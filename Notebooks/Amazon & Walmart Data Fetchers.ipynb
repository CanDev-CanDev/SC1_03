# %%
import requests
from bs4 import BeautifulSoup as bs
from datetime import datetime
import re
import pickle

# %%
class AmazonDataFetcher:
    def __init__(self, session, BASE_URL, default_parser):
        self.session = session
        self.BASE_URL = BASE_URL
        self.DEFAULT_PARSER = default_parser
        self.PRODUCT_REVIEWS = "%s/product-reviews" % self.BASE_URL
        self.PRODUCT_PAGE = "%s/dp" % (self.BASE_URL)
        self.price_pat = r'CDN\$ ([0-9.]+)'
        
    def convert_price(self, price_string):
        return re.findall(self.price_pat, price_string)[0]
        
    def parse_product_page(self, page_content):
        souped = bs(page_content, self.DEFAULT_PARSER)
        return {
            "price": self.convert_price(souped.find("span", {"id": "priceblock_ourprice"}).text),
            "name": souped.find("span", {"id": "productTitle"}).text.strip()
        }
        
    def fetch_product_page(self, URL):
        req = self.session.get(URL)
        return self.parse_product_page(req.content)
        
    def fetch_product_page_from_id(self, product_id):
        return self.fetch_product_page("%s/%s" % (self.PRODUCT_PAGE, product_id,))
        
    def convert_date(self, date_string):
        return datetime.strptime(date_string, "on %B %d, %Y")
        
    def parse_review_box(self, review_box):
        return {
            "review_date": self.convert_date(review_box.find("span", {"data-hook": "review-date"}).text),
            "review_body": review_box.find("span", {"data-hook": "review-body"}).text,
            "review_author": review_box.find("a", {"data-hook": "review-author"})["href"]
        }
        
        
    def parse_page_content(self, page_content):
        souped = bs(page_content, self.DEFAULT_PARSER)
        review_box = souped.find("div", {"id": "cm_cr-review_list"})
        review_boxes = review_box.find_all("div", {"class": "review"})
        next_button = souped.find("li", {"class": "a-last"}).find("a")
        return {
            "reviews": [self.parse_review_box(x) for x in review_boxes],
            "next_page": next_button["href"] if next_button else None
        }
        
        
    def fetch_reviews_from_id(self, product_id):
        req = self.session.get("%s/%s" % (self.PRODUCT_REVIEWS, product_id,))
        return self.parse_page_content(req.content)
        
    def fetch_reviews_on_page(self, URL):
        req = self.session.get(URL)
        return self.parse_page_content(req.content)
    
    def fetch_all_reviews_from_id(self, product_id, max_pages = -1):
        return self.fetch_all_reviews("%s/%s" % (self.PRODUCT_REVIEWS, product_id))
    
    def fetch_all_reviews(self, URL, max_pages=-1):
        url = URL
        reviews = []
        pages = 0
        while (url and pages != max_pages):
            pages += 1
            data = self.fetch_reviews_on_page(url)
            reviews += data["reviews"]
            if (not data["next_page"]):
                break
                
            url = "%s%s" % (self.BASE_URL,data["next_page"],)
        return {
            "reviews": reviews
        }
    
    def fetch_all_data_from_id(self, product_id):
        return {
            "reviews": self.fetch_all_reviews_from_id(product_id),
            "details": self.fetch_product_page_from_id(product_id)
        }

# %%
class WalmartDataFetcher:
    def __init__(self, session):
        self.session = session
        self.BASE_URL = "https://stock.ga/wm"
        self.NEAREST_STORE_URL = "%s/nearest-store.php" % (self.BASE_URL)
        self.AVAILABILITY_URL = "%s/availability.php" % (self.BASE_URL)
        self.SEARCH_URL = "%s/search.php" % (self.BASE_URL)
        
    def fetch_availability(self, upc, storeId):
        req = self.session.get(
            self.AVAILABILITY_URL,
            params = {
                "storeId": storeId,
                "upc": upc,
                "src": "upc"
            }
        )
        return req.json()
    
    def fetch_availability_multi_store(self, upc, stores):
        return [{
            "store": store,
            "details": self.fetch_availability(upc, store.get("storeId"))
        } for store in stores]
    
    def fetch_nearest_store(self, lon, lat, numstores=1):
        req = self.session.get(
            self.NEAREST_STORE_URL, 
            params = {
                "numstores": numstores, 
                "lattitude": lat, 
                "longitude": lon, 
                "showpickuplocation": "false",
                "mystore": ""
            })
        
        return req.json()
    
    def fetch_all_nearest_stores(self, coordinates):
        return [self.fetch_nearest_store(coords["lon"], coords["lat"]) for coords in coordinates]
    
    def parse_search_results(self, search_results):
        return search_results.get("result")[0].get("sku")
    
    
    def fetch_search_and_data(self, query, stores):
        return self.fetch_availability_multi_store(
            self.parse_search_results(self.fetch_search_results(query)),
            stores
        )
    
    def fetch_search_results(self, query):
        req = self.session.get(
            self.SEARCH_URL,
            params = {
                "q": query,
                "n": "60",
                "p": "1"
            }
        )
        
        return req.json()

# %% [markdown]
# #### Parsing text into proper format

# %%
pat = r'(.*), Canada\nLatitude: ([0-9.\-]+) \| Longitude: ([0-9.\-]+)'
data = '''
Winnipeg, MB R3B 1B9, Canada
Latitude: 49.899861 | Longitude: -97.139199
Regina, SK S4P 3C8, Canada
Latitude: 50.451903 | Longitude: -104.614313
Toronto, ON M5H 2N2, Canada
Latitude: 43.652549 | Longitude: -79.383512
Montreal, QC H2Y 1C6, Canada
Latitude: 45.508848 | Longitude: -73.554642
Halifax, NS B3J 3A5, Canada
Latitude: 44.64747 | Longitude: -63.572177
Fredericton, NB E3B 1B5, Canada
Latitude: 45.963394 | Longitude: -66.643218
St. John’s, NL A1C 1J3, Canada
Latitude: 47.560938 | Longitude: -52.713105
Charlottetown, PE C1A 4B7, Canada
Latitude: 46.235603 | Longitude: -63.12992
Edmonton, AB T5J 3E9, Canada
Latitude: 53.544979 | Longitude: -113.49349
Vancouver, BC V5Y 1V4, Canada
Latitude: 49.261057 | Longitude: -123.114077
'''

stores = re.findall(pat, data)

# %%
walmartDataFetcher = WalmartDataFetcher(requests)

# %%
stores = [
    {
        "location": x[0],
        "lat": x[1],
        "lon": x[2]
    } for x in stores
]

# %%
all_store_details = walmartDataFetcher.fetch_all_nearest_stores(stores)

# %% [markdown]
# ### Sanatize data

# %%
all_store_details = [x.get("stores")[0] for x in all_store_details]

# %%
class Main:
    def __init__(self, all_stores):
        self.session = requests.Session()
        self.session.headers.update({"user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.67 Safari/537.36"})
        self.walmartDataFetcher = WalmartDataFetcher(self.session)
        self.amazonDataFetcher = AmazonDataFetcher(self.session, "https://amazon.ca", "lxml")
        self.all_store_details = all_stores
        
    def fetch_product_info_by_id(amazonId, walmartId):
        return {
            "amazon": self.amazonDataFetcher.fetch_all_data_from_id(amazonId),
            "walmart": self.walmartDataFetcher.fetch_availability_multi_store(walmartId, self.all_store_details)
        }
    
    def fetch_product_info_by_amazonId(self, amazonId):
        result = {
            "amazon": self.amazonDataFetcher.fetch_all_data_from_id(amazonId)
        }
        
        result["walmart"] = self.walmartDataFetcher.fetch_search_and_data(result["amazon"]["details"].get("name"), self.all_store_details)
            
            
        return result

# %%
main = Main(all_store_details)

# %%
data = main.fetch_product_info_by_amazonId("B00IZUKDJK")

# %%
data
# Out:
# {'amazon': {'reviews': {'reviews': [{'review_date': datetime.datetime(2016, 8, 17, 0, 0),
#      'review_body': "This deferent smells very clean & I've found it even lasts when the laundry has dried! The inside of the cap shows 1/2/3 for different load sizes but is hard to see. Will buy again, this beats the cheap detergent I normally buy, by far!",
#      'review_author': '/gp/profile/amzn1.account.AEMJ7ISM3CAXP3N4NG3QH5ZHBEJA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 11, 17, 0, 0),
#      'review_body': 'Not quite as good as the real thing, but for the price it still cleans better than the bargain brands. Smells good and makes the laundry smell fresh too.If you found this review helpful, please click the button below to let me know. Thanks!',
#      'review_author': '/gp/profile/amzn1.account.AHKLH2VG5WGDG5M5UEANSYEHR27Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 2, 7, 0, 0),
#      'review_body': 'I usually use fragrance free. After my husband did the laundry using this (and hung some mats to finish drying) I kept sniffing around the house "what\'s that lovely smell?"---Oh, you did the laundry!',
#      'review_author': '/gp/profile/amzn1.account.AEH6PWXVS6II67MYGXBFPED42IAA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 6, 4, 0, 0),
#      'review_body': 'Tide Simply Clean washing liquid works well and our clothes are clean without losing colour.  Laundry comes out smelling nice without being too strong.',
#      'review_author': '/gp/profile/amzn1.account.AF2IQIVYQ5XEKS3B7PEP26DN57EQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 1, 17, 0, 0),
#      'review_body': '💛  Just like all the other Tide products!  Cleans the laundry as it should without destroying it with cheap chemicals. Completely satisfied with this less expensive version of the classic formula.',
#      'review_author': '/gp/profile/amzn1.account.AHQXUKDI4AY4XCDACTPGQHPUMSKA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 4, 26, 0, 0),
#      'review_body': 'This is by far my favourite laundry detergent brand. Does the job and lasts me a long time. It has proven to be very reliable during all the years I have been using it.',
#      'review_author': '/gp/profile/amzn1.account.AEY66PD7RVUTYATR3TM6TG6YFXIA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 5, 4, 0, 0),
#      'review_body': 'I really like the smell of Tide. This arrived promptly with my prime delivery option. Smells good and works!',
#      'review_author': '/gp/profile/amzn1.account.AGTO2C734J4BIOC3MR27JNAYBDEQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 1, 12, 0, 0),
#      'review_body': 'great product, good price',
#      'review_author': '/gp/profile/amzn1.account.AEQIMEGOMXE32R6M3DOTO7N45X5A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 2, 3, 0, 0),
#      'review_body': 'Great Product !',
#      'review_author': '/gp/profile/amzn1.account.AHA7VGFPQNKFJKJY4TMLZD6JUTWA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 10, 13, 0, 0),
#      'review_body': 'Good value and fast shipping',
#      'review_author': '/gp/profile/amzn1.account.AHFWJJESPKREMM6GWZ2WH6Y3VEWA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 4, 27, 0, 0),
#      'review_body': 'Tide is great. Product came as described',
#      'review_author': '/gp/profile/amzn1.account.AG77JQ4ZLIS5LJ4Q6X3JHOMY2LBA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 4, 6, 0, 0),
#      'review_body': 'Really good !',
#      'review_author': '/gp/profile/amzn1.account.AEYRZ5EL3MCBSGQHTYTMFBE3DJMA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 3, 22, 0, 0),
#      'review_body': 'smells great, works great',
#      'review_author': '/gp/profile/amzn1.account.AGA7WF337S5A5PDAUDA23K47MNFQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 6, 9, 0, 0),
#      'review_body': 'bien',
#      'review_author': '/gp/profile/amzn1.account.AGH4WQX36UICW66PHKPYMNROW6FQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 8, 12, 0, 0),
#      'review_body': 'it does the job.',
#      'review_author': '/gp/profile/amzn1.account.AHCZMZDTHQMGE45ZKRERZK2ZJZ3Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 1, 3, 0, 0),
#      'review_body': 'Good',
#      'review_author': '/gp/profile/amzn1.account.AG5OMFEGNSTEIXO3RW52MPLPEJTA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 9, 29, 0, 0),
#      'review_body': 'I love the smell.',
#      'review_author': '/gp/profile/amzn1.account.AGE4XKDKKQ2W7KJCEW7JTTPGV7JA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 9, 2, 0, 0),
#      'review_body': 'Good product!',
#      'review_author': '/gp/profile/amzn1.account.AEQ2RIZAXB5BWSSBI4VUOHURU44A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2014, 9, 6, 0, 0),
#      'review_body': 'Simple n clean.',
#      'review_author': '/gp/profile/amzn1.account.AGMEFKSERVUJRDDZT67VDDJGP3KA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 2, 11, 0, 0),
#      'review_body': "Been using this as a laundry detergent for my family's needs. It has just the right amount of clean. Does the job well. Good buy especially if subscribe and save.",
#      'review_author': '/gp/profile/amzn1.account.AEEJEVSZ6TBMUTTJTVSKYOP7QV3A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 7, 23, 0, 0),
#      'review_body': 'Expensive and Sucks, Communist Red Brand Promoted by PRC Communist DJ 海清',
#      'review_author': '/gp/profile/amzn1.account.AHVVZNZDX2Y5HAS3BRGD4GZ4EGKQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 2, 7, 0, 0),
#      'review_body': 'good value',
#      'review_author': '/gp/profile/amzn1.account.AEYB55FELNVR37OITSN2FRRPMGPA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 11, 19, 0, 0),
#      'review_body': 'Worst Tide Smell! The fragrance is VERY strong and pungent. Stick with Tide Original.',
#      'review_author': '/gp/profile/amzn1.account.AEB3LJ74PJLP7QSVCSQL46VAJLPQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 11, 2, 0, 0),
#      'review_body': "Prior to using this detergent I had bought Purex because it frequently went on sale and was nearly half the cost of this one.My local grocery store had the Tide Simply Clean marked down one week and I decided to get a few bottles of it to see how well this worked. So glad I did get it because I love it!It cleans so well and leaves my clothes smelling great. My husband even mentioned how he liked the scent. I used to have to buy the scented beads and crystals so my clothes would smell fresh, but I found I haven't needed it with this. It works just as well as regular Tide for cleaning and is so much cheaper.",
#      'review_author': '/gp/profile/amzn1.account.AELLS6WQQN4CVF3ST3ZDSLDZ5UWA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 4, 18, 0, 0),
#      'review_body': "As advertised, but doesn't quite clean as well as other brands. Good in a pinch. Fragrance is stronger than I would like.",
#      'review_author': '/gp/profile/amzn1.account.AGSECNJA5UVMTPWIHKB7SQRSOQCQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 2, 14, 0, 0),
#      'review_body': 'excellent!! Does many loads of wash and smells nice',
#      'review_author': '/gp/profile/amzn1.account.AGMF77U7XORJIY6GU6EASYSCZD6Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 5, 21, 0, 0),
#      'review_body': 'Any Tide products are perfect. The price was right too.',
#      'review_author': '/gp/profile/amzn1.account.AFSCZTYGEWLF4B72GLGAGPJFFYGA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 6, 24, 0, 0),
#      'review_body': "Used to be smelly, now I'm so fresh and so clean... clean",
#      'review_author': '/gp/profile/amzn1.account.AG77JQ4ZLIS5LJ4Q6X3JHOMY2LBA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 15, 0, 0),
#      'review_body': 'pretty good deal!',
#      'review_author': '/gp/profile/amzn1.account.AGMF77U7XORJIY6GU6EASYSCZD6Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 8, 19, 0, 0),
#      'review_body': 'Purchased 9 of these and only got two!!',
#      'review_author': '/gp/profile/amzn1.account.AFQQPIHGNCIFYRF4TH6NNWTIW3IQ/ref=cm_cr_arp_d_pdp?ie=UTF8'}]},
#   'details': {'price': '18.49',
#    'name': 'Tide HEC Simply Clean & Fresh Refreshing Breeze Liquid Laundry Detergent 1.77L 38loads'}},
#  'walmart': [{'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '49.895849,-97.195621',
#     'storeCustomMessage': '',
#     'storeId': '3116',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 0,
#        'maxRegularPrice': 0,
#        'minCurrentPrice': 0,
#        'maxCurrentPrice': 0,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'NotSold',
#        'storeNumber': '3116',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'NotSold',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 0,
#       'maxRegularPrice': 0,
#       'minCurrentPrice': 0,
#       'maxCurrentPrice': 0}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '50.496571,-104.637024',
#     'storeCustomMessage': '',
#     'storeId': '3076',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 0,
#        'maxRegularPrice': 0,
#        'minCurrentPrice': 0,
#        'maxCurrentPrice': 0,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'NotSold',
#        'storeNumber': '3076',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'NotSold',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 0,
#       'maxRegularPrice': 0,
#       'minCurrentPrice': 0,
#       'maxCurrentPrice': 0}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '43.668635,-79.338302',
#     'storeCustomMessage': '',
#     'storeId': '1150',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 0,
#        'maxRegularPrice': 0,
#        'minCurrentPrice': 0,
#        'maxCurrentPrice': 0,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'NotSold',
#        'storeNumber': '1150',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'NotSold',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 0,
#       'maxRegularPrice': 0,
#       'minCurrentPrice': 0,
#       'maxCurrentPrice': 0}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '45.502980,-73.637075',
#     'storeCustomMessage': '',
#     'storeId': '1170',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 0,
#        'maxRegularPrice': 0,
#        'minCurrentPrice': 0,
#        'maxCurrentPrice': 0,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'NotSold',
#        'storeNumber': '1170',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'NotSold',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 0,
#       'maxRegularPrice': 0,
#       'minCurrentPrice': 0,
#       'maxCurrentPrice': 0}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '44.647284,-63.619071',
#     'storeCustomMessage': '',
#     'storeId': '3636',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 0,
#        'maxRegularPrice': 0,
#        'minCurrentPrice': 0,
#        'maxCurrentPrice': 0,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'NotSold',
#        'storeNumber': '3636',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'NotSold',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 0,
#       'maxRegularPrice': 0,
#       'minCurrentPrice': 0,
#       'maxCurrentPrice': 0}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '45.986020,-66.627044',
#     'storeCustomMessage': '',
#     'storeId': '1067',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 0,
#        'maxRegularPrice': 0,
#        'minCurrentPrice': 0,
#        'maxCurrentPrice': 0,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'NotSold',
#        'storeNumber': '1067',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'NotSold',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 0,
#       'maxRegularPrice': 0,
#       'minCurrentPrice': 0,
#       'maxCurrentPrice': 0}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '47.532781,-52.751715',
#     'storeCustomMessage': '',
#     'storeId': '1179',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 0,
#        'maxRegularPrice': 0,
#        'minCurrentPrice': 0,
#        'maxCurrentPrice': 0,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'NotSold',
#        'storeNumber': '1179',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'NotSold',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 0,
#       'maxRegularPrice': 0,
#       'minCurrentPrice': 0,
#       'maxCurrentPrice': 0}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '46.262392,-63.152691',
#     'storeCustomMessage': '',
#     'storeId': '3162',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 0,
#        'maxRegularPrice': 0,
#        'minCurrentPrice': 0,
#        'maxCurrentPrice': 0,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'NotSold',
#        'storeNumber': '3162',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'NotSold',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 0,
#       'maxRegularPrice': 0,
#       'minCurrentPrice': 0,
#       'maxCurrentPrice': 0}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '53.538011,-113.420372',
#     'storeCustomMessage': '',
#     'storeId': '3026',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 0,
#        'maxRegularPrice': 0,
#        'minCurrentPrice': 0,
#        'maxCurrentPrice': 0,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'NotSold',
#        'storeNumber': '3026',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'NotSold',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 0,
#       'maxRegularPrice': 0,
#       'minCurrentPrice': 0,
#       'maxCurrentPrice': 0}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '49.259280,-123.027429',
#     'storeCustomMessage': '',
#     'storeId': '1104',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 0,
#        'maxRegularPrice': 0,
#        'minCurrentPrice': 0,
#        'maxCurrentPrice': 0,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'NotSold',
#        'storeNumber': '1104',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'NotSold',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 0,
#       'maxRegularPrice': 0,
#       'minCurrentPrice': 0,
#       'maxCurrentPrice': 0}}}}]}
