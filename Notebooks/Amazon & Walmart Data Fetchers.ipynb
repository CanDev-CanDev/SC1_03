# %%
import requests
from bs4 import BeautifulSoup as bs
from datetime import datetime
import re
import pickle

# %%
class AmazonDataFetcher:
    def __init__(self, session, BASE_URL, default_parser):
        self.session = session
        self.BASE_URL = BASE_URL
        self.DEFAULT_PARSER = default_parser
        self.PRODUCT_REVIEWS = "%s/product-reviews" % self.BASE_URL
        self.PRODUCT_PAGE = "%s/dp" % (self.BASE_URL)
        self.price_pat = r'CDN\$ ([0-9.]+)'
        
    def convert_price(self, price_string):
        return re.findall(self.price_pat, price_string)[0]
        
    def parse_product_page(self, page_content):
        souped = bs(page_content, self.DEFAULT_PARSER)
        return {
            "price": self.convert_price(souped.find("span", {"id": "priceblock_ourprice"}).text),
            "name": souped.find("span", {"id": "productTitle"}).text.strip()
        }
        
    def fetch_product_page(self, URL):
        req = self.session.get(URL)
        return self.parse_product_page(req.content)
        
    def fetch_product_page_from_id(self, product_id):
        return self.fetch_product_page("%s/%s" % (self.PRODUCT_PAGE, product_id,))
        
    def convert_date(self, date_string):
        return datetime.strptime(date_string, "on %B %d, %Y")
        
    def parse_review_box(self, review_box):
        return {
            "review_date": self.convert_date(review_box.find("span", {"data-hook": "review-date"}).text),
            "review_body": review_box.find("span", {"data-hook": "review-body"}).text,
            "review_author": review_box.find("a", {"data-hook": "review-author"})["href"]
        }
        
        
    def parse_page_content(self, page_content):
        souped = bs(page_content, self.DEFAULT_PARSER)
        review_box = souped.find("div", {"id": "cm_cr-review_list"})
        review_boxes = review_box.find_all("div", {"class": "review"})
        next_button = souped.find("li", {"class": "a-last"}).find("a")
        return {
            "reviews": [self.parse_review_box(x) for x in review_boxes],
            "next_page": next_button["href"] if next_button else None
        }
        
        
    def fetch_reviews_from_id(self, product_id):
        req = self.session.get("%s/%s" % (self.PRODUCT_REVIEWS, product_id,))
        return self.parse_page_content(req.content)
        
    def fetch_reviews_on_page(self, URL):
        req = self.session.get(URL)
        return self.parse_page_content(req.content)
    
    def fetch_all_reviews_from_id(self, product_id, max_pages = -1):
        return self.fetch_all_reviews("%s/%s" % (self.PRODUCT_REVIEWS, product_id))
    
    def fetch_all_reviews(self, URL, max_pages=-1):
        url = URL
        reviews = []
        pages = 0
        while (url and pages != max_pages):
            pages += 1
            data = self.fetch_reviews_on_page(url)
            reviews += data["reviews"]
            if (not data["next_page"]):
                break
                
            url = "%s%s" % (self.BASE_URL,data["next_page"],)
        return {
            "reviews": reviews
        }
    
    def fetch_all_data_from_id(self, product_id):
        return {
            "reviews": self.fetch_all_reviews_from_id(product_id),
            "details": self.fetch_product_page_from_id(product_id)
        }

# %%
class WalmartDataFetcher:
    def __init__(self, session):
        self.session = session
        self.BASE_URL = "https://stock.ga/wm"
        self.NEAREST_STORE_URL = "%s/nearest-store.php" % (self.BASE_URL)
        self.AVAILABILITY_URL = "%s/availability.php" % (self.BASE_URL)
        self.SEARCH_URL = "%s/search.php" % (self.BASE_URL)
        
    def fetch_availability(self, upc, storeId):
        req = requests.get(
            self.AVAILABILITY_URL,
            params = {
                "storeId": storeId,
                "upc": upc,
                "src": "upc"
            }
        )
        return req.json()
    
    def fetch_availability_multi_store(self, upc, stores):
        return [{
            "store": store,
            "details": self.fetch_availability(upc, store.get("storeId"))
        } for store in stores]
    
    def fetch_nearest_store(self, lon, lat, numstores=1):
        req = self.session.get(
            self.NEAREST_STORE_URL, 
            params = {
                "numstores": numstores, 
                "lattitude": lat, 
                "longitude": lon, 
                "showpickuplocation": "false",
                "mystore": ""
            })
        
        return req.json()
    
    def fetch_all_nearest_stores(self, coordinates):
        return [self.fetch_nearest_store(coords["lon"], coords["lat"]) for coords in coordinates]
    
    def parse_search_results(self, search_results):
        return search_results.get("result")[0].get("sku")
    
    
    def fetch_search_and_data(self, query, stores):
        return self.fetch_availability_multi_store(
            self.parse_search_results(self.fetch_search_results(query)),
            stores
        )
    
    def fetch_search_results(self, query):
        req = self.session.get(
            self.SEARCH_URL,
            params = {
                "q": query,
                "n": "60",
                "p": "1"
            }
        )
        
        return req.json()

# %% [markdown]
# #### Parsing text into proper format

# %%
pat = r'(.*), Canada\nLatitude: ([0-9.\-]+) \| Longitude: ([0-9.\-]+)'
data = '''
Winnipeg, MB R3B 1B9, Canada
Latitude: 49.899861 | Longitude: -97.139199
Regina, SK S4P 3C8, Canada
Latitude: 50.451903 | Longitude: -104.614313
Toronto, ON M5H 2N2, Canada
Latitude: 43.652549 | Longitude: -79.383512
Montreal, QC H2Y 1C6, Canada
Latitude: 45.508848 | Longitude: -73.554642
Halifax, NS B3J 3A5, Canada
Latitude: 44.64747 | Longitude: -63.572177
Fredericton, NB E3B 1B5, Canada
Latitude: 45.963394 | Longitude: -66.643218
St. John’s, NL A1C 1J3, Canada
Latitude: 47.560938 | Longitude: -52.713105
Charlottetown, PE C1A 4B7, Canada
Latitude: 46.235603 | Longitude: -63.12992
Edmonton, AB T5J 3E9, Canada
Latitude: 53.544979 | Longitude: -113.49349
Vancouver, BC V5Y 1V4, Canada
Latitude: 49.261057 | Longitude: -123.114077
'''

stores = re.findall(pat, data)

# %%
walmartDataFetcher = WalmartDataFetcher(requests)

# %%
stores = [
    {
        "location": x[0],
        "lat": x[1],
        "lon": x[2]
    } for x in stores
]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-136-ac2224bfed22> in <module>
#       4         "lat": x[1],
#       5         "lon": x[2]
# ----> 6     } for x in stores
#       7 ]
#
# <ipython-input-136-ac2224bfed22> in <listcomp>(.0)
#       4         "lat": x[1],
#       5         "lon": x[2]
# ----> 6     } for x in stores
#       7 ]
#
# KeyError: 0

# %%
all_store_details = walmartDataFetcher.fetch_all_nearest_stores(stores)

# %% [markdown]
# ### Sanatize data

# %%
all_store_details = [x.get("stores")[0] for x in all_store_details]

# %%
class Main:
    def __init__(self, all_stores):
        self.session = requests.Session()
        self.session.headers.update({"user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.67 Safari/537.36"})
        self.walmartDataFetcher = WalmartDataFetcher(self.session)
        self.amazonDataFetcher = AmazonDataFetcher(self.session, "https://amazon.ca", "lxml")
        self.all_store_details = all_stores
        
    def fetch_product_info_by_id(self, amazonId, walmartId):
        return {
            "amazon": self.amazonDataFetcher.fetch_all_data_from_id(amazonId),
            "walmart": self.walmartDataFetcher.fetch_availability_multi_store(walmartId, self.all_store_details)
        }
    
    def fetch_product_info_by_amazonId(self, amazonId):
        result = {
            "amazon": self.amazonDataFetcher.fetch_all_data_from_id(amazonId)
        }
        
        result["walmart"] = self.walmartDataFetcher.fetch_search_and_data(result["amazon"]["details"].get("name"), self.all_store_details)
            
            
        return result

# %%
main = Main(all_store_details)

# %%
output = main.fetch_product_info_by_id("B00BIMZ10I", "63050955708")

# %%
output
# Out:
# {'amazon': {'reviews': {'reviews': [{'review_date': datetime.datetime(2017, 11, 8, 0, 0),
#      'review_body': "Cleans well without all the harsh chemicals and perfumes. Became highly sensitive to perfumes during pregnancy and it continued after having my daughter.Already had a different detergent for my newborn so when I quickly went through the bottle at $20 wasn't appealing. Did some research and glad that to have found this detergent. It is safe to use for the whole family, great price for the size!Continue the same routinue of pretreating stains and clothes come out clean, stain free and no skin reactions.",
#      'review_author': '/gp/profile/amzn1.account.AFS7WZSFE4OZHH7XHDSNSRVWZSTQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 17, 0, 0),
#      'review_body': "This detergent is amazing if you or your children have eczema or allergies to dyes or fragrances. I have axcusively used this detergent for very terrible case of eczema and it has helped a lot. If I run out of Tide Free & Gentle (while traveling or at home) and use another type of detergent my child's eczema flairs up again. Recommend you try Tide Free & GentleAmazon also delivered quickly & the package went damaged!",
#      'review_author': '/gp/profile/amzn1.account.AHPHQM46AI3P7A6ZX4YYSVZ7YRIQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 9, 4, 0, 0),
#      'review_body': 'Maybe its just me but Tide seems to clean betterand since I use a bit less then other brands, the same size containersseem to last longer as well.I only buy free and clear products "why the need for colors or other chemicals? it never made sense to me"',
#      'review_author': '/gp/profile/amzn1.account.AGV7TVZ4RURHSTHD22TSGOEXBP2A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 7, 18, 0, 0),
#      'review_body': "Je n'ai rien contre le produit, mais contre la réception du produit par Amazon. Lorsque j'ai ouvert la boîte, le savon avait coulé (environ une tasse). Il n'y avait que 2 feuilles de papier pour emballer le produit... ce qui est insuffisant compte tenu du poids du Tide.",
#      'review_author': '/gp/profile/amzn1.account.AHIHS4J2JVGWN7UWESOW23R3J4XQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 3, 21, 0, 0),
#      'review_body': "Does not smell at all. Yay!!Won't cover up your stinky front loader laundry machine smell. Boo :((Borax will get rid of that musty smell in your machine and on your clothes if they smell like your machine).",
#      'review_author': '/gp/profile/amzn1.account.AGZD3MVW5FAOKLQCKL3O4L5J7UAQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 3, 4, 0, 0),
#      'review_body': 'Great price, and perfect if you have sensitive skin or are washing baby clothes. I noticed a difference when switching from regular detergent. Skin was definitely less itchy!',
#      'review_author': '/gp/profile/amzn1.account.AGNKI2OQ75PBD5RONKCQUGB4IY6Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 1, 27, 0, 0),
#      'review_body': "I have used Tide all of my adult life. It is a great detergent that truly gets clothes clean. When the manufacturer started to put the sweet perfume scent into 'original' Tide my allergies went wild, so I switched to this.  I'm so glad there is a scent free version of my favourite laundry detergent.",
#      'review_author': '/gp/profile/amzn1.account.AECXGM3RLPRLANNKCZOBENOR5NTQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 4, 7, 0, 0),
#      'review_body': "Gentle detergent for baby's clothes that can also be used for our regular laundry.",
#      'review_author': '/gp/profile/amzn1.account.AGQZDOVUADS37YQXIF5M5XH737OQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 2, 7, 0, 0),
#      'review_body': 'not sure if it is better for sensitive skin than the normal stuff but it works great',
#      'review_author': '/gp/profile/amzn1.account.AH3R5SNSM4T3MNIFR6EGEUP53I5A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 9, 23, 0, 0),
#      'review_body': 'I have been using Free & Gentle for a year now and am very pleased with the formula. I have skin allergies and I have no trouble with this product.',
#      'review_author': '/gp/profile/amzn1.account.AHO3P5U6NZGBQNNCFS3D2E6GHBTQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 8, 17, 0, 0),
#      'review_body': 'I wash my fitted compression socks with Tide Free and Gentle it cleans them well and I have no problem with wear in the elastic build.',
#      'review_author': '/gp/profile/amzn1.account.AHLEOJXO3CDFVXSSTFDL2VRKK5MA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 3, 27, 0, 0),
#      'review_body': 'I got this product for my daughter because of allergies. So far she has had no complaints of skin irritation.',
#      'review_author': '/gp/profile/amzn1.account.AGWFISEUPIXJRGQ3JJJ4HMWPYJIQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 10, 27, 0, 0),
#      'review_body': 'Non scented product that gets my cloathes clean! Good quality & price.',
#      'review_author': '/gp/profile/amzn1.account.AEOUA6UOWSHRSZOS7TLTOTPERYTA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 7, 16, 0, 0),
#      'review_body': 'does what it is supposed to do.  Should make all detergents fragrant free',
#      'review_author': '/gp/profile/amzn1.account.AFHS73QZWSPINC26L3DG4KM6XFDA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 5, 9, 0, 0),
#      'review_body': 'Good deal and very fast service. I received the order one day earlier than the schedule and very happy with the package.',
#      'review_author': '/gp/profile/amzn1.account.AHC5L2BW667EOHWBBO7TYC4G33JQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 12, 16, 0, 0),
#      'review_body': 'I found a product that I can use on my sensitive skin!',
#      'review_author': '/gp/profile/amzn1.account.AH4LBNTPPAXLJSUPYFQ7OZGOLTJQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 7, 30, 0, 0),
#      'review_body': 'Good value and quick delivery to the door.',
#      'review_author': '/gp/profile/amzn1.account.AGA6RLJLWIUMUBGYHC745JYWPXBA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 12, 22, 0, 0),
#      'review_body': 'Great prrrroduct cleanse well',
#      'review_author': '/gp/profile/amzn1.account.AFZSDO74TNEPMLFXMFAE4JCUKZWQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2014, 7, 1, 0, 0),
#      'review_body': 'Excellent product, no reaction on my kids sensitive skin. Love the pour spout for ease of dispensing. Will defiantly order this product again and again.',
#      'review_author': '/gp/profile/amzn1.account.AHUYNO2YOTGWFUIRPHC6D6V3JQTA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 3, 31, 0, 0),
#      'review_body': 'the best',
#      'review_author': '/gp/profile/amzn1.account.AHNOL4656V5JYJOGYMTV4RBSOTQA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 6, 28, 0, 0),
#      'review_body': 'My youngest daughter has sensitive skin no rashes since we began this tide product.',
#      'review_author': '/gp/profile/amzn1.account.AHVMPTQDHXWLSJ3MNZICTSCDW2HA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 12, 30, 0, 0),
#      'review_body': 'Would buy this product again to wash newborn clothing.',
#      'review_author': '/gp/profile/amzn1.account.AERV35JPCH7L7ALBROTWBJ6YMMTA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 11, 29, 0, 0),
#      'review_body': 'So much better then the smaller containers',
#      'review_author': '/gp/profile/amzn1.account.AFAUHW6SYNRCBEFWUWJQL6TKK5UA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 5, 0, 0),
#      'review_body': 'Perfect for my toddlers with sensitive skin.  Still gets the job done on my clothes too.',
#      'review_author': '/gp/profile/amzn1.account.AHIR4ZQURJV4BSFUVQV5RSMAJUYQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 15, 0, 0),
#      'review_body': 'Good product and will re-order when needed.',
#      'review_author': '/gp/profile/amzn1.account.AE6TQIGZJ77ONZ23OG4G7K6OBYMQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 3, 23, 0, 0),
#      'review_body': 'arrived on time, great product, good price.',
#      'review_author': '/gp/profile/amzn1.account.AEH2HMHSX26TOJHRILE2OVBCCE3Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 25, 0, 0),
#      'review_body': 'Bottle leaked and made a mess!',
#      'review_author': '/gp/profile/amzn1.account.AFWA4OYWIBGC6B5OAMPFVYW6DVRA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 9, 20, 0, 0),
#      'review_body': 'Not scented at all, cleans well and is high efficiency.',
#      'review_author': '/gp/profile/amzn1.account.AGNF2CO5UNIQ6U7DAL2YAKXI6FGQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 7, 7, 0, 0),
#      'review_body': 'excellent prix et produit parfait pour peau fragile',
#      'review_author': '/gp/profile/amzn1.account.AELV7GYTVKCOPYRBMD5F45QMN7FQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 7, 3, 0, 0),
#      'review_body': 'Great clean without fake perfume smells.',
#      'review_author': '/gp/profile/amzn1.account.AETEVGO44CVT6EDJQNNHLWE4IQ2Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 8, 12, 0, 0),
#      'review_body': 'Had to use this type of soap due to an allergy',
#      'review_author': '/gp/profile/amzn1.account.AECSLFHXFJEFIGBJZB7GUTYTIPLA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 9, 4, 0, 0),
#      'review_body': 'Great',
#      'review_author': '/gp/profile/amzn1.account.AEUZAJ5EYCRUJA7S5E6W27AQAD3A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 10, 25, 0, 0),
#      'review_body': 'This was smaller than I expected!',
#      'review_author': '/gp/profile/amzn1.account.AG6XGRZ3FIWASNC2PV4S6O7P4Z5Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 6, 8, 0, 0),
#      'review_body': 'GREAT',
#      'review_author': '/gp/profile/amzn1.account.AGSN7ZEHSHB6NDFDE36LGHMAA6JQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 5, 13, 0, 0),
#      'review_body': 'Great for my newborn baby.',
#      'review_author': '/gp/profile/amzn1.account.AHN3PNFKWH5GXIBHSHCZSQXELEPA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 3, 0, 0),
#      'review_body': "Haven't used yet but sure it will be great",
#      'review_author': '/gp/profile/amzn1.account.AHZBU2DKZD45BAUFSBMESIKHJXIA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 8, 2, 0, 0),
#      'review_body': 'I can now clean my clothes',
#      'review_author': '/gp/profile/amzn1.account.AFN56ESI7IS5ZGZNLS3GLFVWE75Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 8, 6, 0, 0),
#      'review_body': 'Good product. No irritations on baby skin',
#      'review_author': '/gp/profile/amzn1.account.AHRA6SXR2BVVUFL2DOC2AFINI7PQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 4, 29, 0, 0),
#      'review_body': 'Excellent',
#      'review_author': '/gp/profile/amzn1.account.AGE33ZXKADZ6PCK3IPJBDMYBWL4A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 8, 14, 0, 0),
#      'review_body': 'This does not clean clothes and leaves a mark on them.',
#      'review_author': '/gp/profile/amzn1.account.AGN327G5W5DBXX7TVBEZDAKLUHNQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 1, 29, 0, 0),
#      'review_body': 'value',
#      'review_author': '/gp/profile/amzn1.account.AFFRATN3G2G4L7JCFEDNONW37YVQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 7, 11, 0, 0),
#      'review_body': 'cleans clothes',
#      'review_author': '/gp/profile/amzn1.account.AGOITG6SSE74IPEMX6HG7DH4RX4A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 8, 3, 0, 0),
#      'review_body': 'Love Tide Free. Great product.',
#      'review_author': '/gp/profile/amzn1.account.AHEDSMFOTR3RQ4TOBVCCJ55Q4LDQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 8, 18, 0, 0),
#      'review_body': 'Works good',
#      'review_author': '/gp/profile/amzn1.account.AHKTPN4AQ6ZFTY4F6NZKST4DIBIQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2014, 10, 20, 0, 0),
#      'review_body': 'Works the best.',
#      'review_author': '/gp/profile/amzn1.account.AHLQU3SQTN2JXONPQPA7LZS24OLA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2014, 7, 10, 0, 0),
#      'review_body': 'very good',
#      'review_author': '/gp/profile/amzn1.account.AGFJPPG7BIII2S4AM2IDFLOS4PCQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 9, 28, 0, 0),
#      'review_body': 'Great price',
#      'review_author': '/gp/profile/amzn1.account.AGJXCIF5IFLBXW3ZDNJZBCWHZQIA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 6, 15, 0, 0),
#      'review_body': 'Perfect',
#      'review_author': '/gp/profile/amzn1.account.AELPSGNSGQXJYJWM7S2NCDCUKYXQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2014, 10, 12, 0, 0),
#      'review_body': 'Great product!',
#      'review_author': '/gp/profile/amzn1.account.AHTHZIID7ILFUNPUNCZV33CUL7OQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 6, 4, 0, 0),
#      'review_body': 'Excellent! Thanks!',
#      'review_author': '/gp/profile/amzn1.account.AE2NNSRHP2OTDIF3WXITBFETJDTA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 2, 20, 0, 0),
#      'review_body': 'I wish there was even a little fragrance to this',
#      'review_author': '/gp/profile/amzn1.account.AGRM7E7WRPV5PLV6C5WZNGUFIFBQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 6, 4, 0, 0),
#      'review_body': "AWFUL both cold washes (reg. baby clothes) and hot washes (diapers) come out with a stale gym locker smell. I washed my clothes in this too,  before I realized, big mistake as I had to go buy good detergent and re-wash absolutely everything I washed in this to get rid of the smell. To top it off my toddler got a rash like none she's ever gotten before from the diapers washed in this stuff, I would give this zero stars if I could. I'd return it but it'd cost me as much in shipping since it's practically full!",
#      'review_author': '/gp/profile/amzn1.account.AGRNPJWEVIBCMM4IFU5EEGHEHPVA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2014, 11, 1, 0, 0),
#      'review_body': 'Unthoughtful bottle design. It make a lot of mess around the cap.',
#      'review_author': '/gp/profile/amzn1.account.AH7HVO7ZJVVCDJB2TOOSPAN5FFNA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 2, 17, 0, 0),
#      'review_body': 'I buy a larger size after using it. It make my cloth in a nature and soft state without using any softener. The most satisfied me is the thing that it will not make my hands feel that much dry if I washing something with my hands directly.',
#      'review_author': '/gp/profile/amzn1.account.AFVOOCWVRARKB7ZEWTVT3QPLGJ2Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 8, 22, 0, 0),
#      'review_body': 'great price',
#      'review_author': '/gp/profile/amzn1.account.AHL52K443SFJRE3SQF44APCG4IAQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 6, 7, 0, 0),
#      'review_body': "It's tide.It cleans clothes. My clothes are clean and I didn't have to go to the store.",
#      'review_author': '/gp/profile/amzn1.account.AFE6KNBFFPHYDIWSCCKWX3E77HOQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 5, 5, 0, 0),
#      'review_body': 'Does the job.',
#      'review_author': '/gp/profile/amzn1.account.AHCQYA7CWSLMNFMDHN67MYSUOLBQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 11, 23, 0, 0),
#      'review_body': 'As described.',
#      'review_author': '/gp/profile/amzn1.account.AHPQK44TTQ3WLC3AJCRYJW5GOFWA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 11, 19, 0, 0),
#      'review_body': 'great price with the discount coupon plus free delivery',
#      'review_author': '/gp/profile/amzn1.account.AEGRL2BMM3CBZHVJADONPMV32NUQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 8, 22, 0, 0),
#      'review_body': 'Good!',
#      'review_author': '/gp/profile/amzn1.account.AEKROKR7VHAPFW2INK36BVCPEJPQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 3, 12, 0, 0),
#      'review_body': 'Clean',
#      'review_author': '/gp/profile/amzn1.account.AEDWHXNGANPKZXMPXPBALR7M2JAQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 7, 0, 0),
#      'review_body': 'Pas de bouchon pour mesurer',
#      'review_author': '/gp/profile/amzn1.account.AE6XP66YFEBTOGIOH5VOQ6DXODYQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 1, 8, 0, 0),
#      'review_body': "I've struggled with allergic contact dermatitis from laundry detergent in the past (specifically Tide Original and various no-name brands) so I was extremely hesitant to try Tide Free & Gentle. Buying laundry detergent is always a gamble, and in the past my only options were scented or natural detergents, which just don't clean as well. I'm glad I took a chance though, I've had no reaction in the three months I've used it and I love the formula.",
#      'review_author': '/gp/profile/amzn1.account.AGD53JHEOHKOIVFDA332YEH26NMA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 4, 19, 0, 0),
#      'review_body': "We love this laundry detergent. Our son has chronic eczema, and this is one of the few laundry detergents that we can use that don't trigger a flare up. It has no perfumes and no dyes, so it is great for people with sensitive skin. And, it leaves clothes clean and fresh smelling, without any artificial scents.Do note that this is a rather small bottle--about 1L, which is approx. 24 loads. It is a good size to travel with if you will be doing laundry while away and want to make sure you have some gentle detergent.",
#      'review_author': '/gp/profile/amzn1.account.AGXAZQJKCXSGII343A2MJJAW27DA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 12, 10, 0, 0),
#      'review_body': "We love tide free and gentle. It has no scent and is gentle enough for my newborn's clothes. We use it for the whole family. It is tough enough to use with cold water as well. This is also an excellent detergent for cloth diapers! I have eczema and this is the only detergent I use. Works great in our high efficiency machine. Not that you have to loosen the cap to get the detergent to flow out. My only complaint is with the measuring cup - if you place it back on the bottle after using, detergent residue will slowly run from the cap onto the bottle and it gets messy. On normal bottles, this residue runs back into the bottle. I'm not sure how Tide could improve this design. I've just stopped putting the measuring cap back on. It is really nice to be able to order heavy products like this and have them delivered right to your door.",
#      'review_author': '/gp/profile/amzn1.account.AF6JU4YTTQXWL4WY2QZQO774NZQQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 7, 11, 0, 0),
#      'review_body': 'Works great. I pay extra for Tide, because it actually works. Also love buying heavy stuff on amazon, because I don’t have a car. This way I don’t have to lug it home from the grocery store.',
#      'review_author': '/gp/profile/amzn1.account.AGFSN7G6IKCTVCUES7KI2Y6C7FZQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 8, 28, 0, 0),
#      'review_body': "Wonderful detergent for sensitive skin and noses. I cannot stand heavily fragranced products, and there's no need to have that on your skin either. If strong, artificial smells that many laundry products have bother you, this is the one to get.",
#      'review_author': '/gp/profile/amzn1.account.AFGXC3ORKHQRM2WIJ2L2HGEUAWSQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 4, 13, 0, 0),
#      'review_body': 'I use this because I have sensitive skin and now with a baby we can use one laundry detergent instead of buying the baby brand as well as this. Super gentle and no skin irritation for anyone in our family. Clothes come out clean. Would highly recommend.',
#      'review_author': '/gp/profile/amzn1.account.AHBVRDUH54XSC66CUF44YMNNTANQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 11, 0, 0),
#      'review_body': 'I switched from regular tide to Tide Free thinking it would be better for my skin. It was actually worse. It took breaking out with an allergic reaction more than once before I realized it was the new detergent causing the problem. Not recommended for people with sensitive skin.',
#      'review_author': '/gp/profile/amzn1.account.AEZVIOL3ALKNRE3YEMIFBY2FZLGQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 1, 25, 0, 0),
#      'review_body': 'Works great, we always get this one now.  I like the zero perfume.  I have no idea why people want to walk around smelling like the soap isle at the grocery store.',
#      'review_author': '/gp/profile/amzn1.account.AFVXYFZ6XEE3MQ3WZDNQOHPSZWNQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 7, 11, 0, 0),
#      'review_body': "Found the pods weren't working well for us. Decided to give this a try. So far. So good. Will update. Price was good too especially with the subscribe and save. We are all very sensitive to smells in our home and this is a lifesaver.",
#      'review_author': '/gp/profile/amzn1.account.AHE6T7DSEBVGK6W44MQMNDSPURRQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 6, 2, 0, 0),
#      'review_body': 'I have very sensitive skin and this is the only detergent that doesn\'t irritate me! It doesn;t have much of a scent, so if you\'re looking for that "laundry smell" this may not be the product for you, but for all of you sensitive/allergic people, it\'s great!',
#      'review_author': '/gp/profile/amzn1.account.AG3QQOWHSW2435PPPHALMJAE6BKQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 5, 21, 0, 0),
#      'review_body': "I use this detergent when I'm cleaning my guinea pigs' bedding and fleece tunnels and whatnot. It's gentle on fabrics and leaves no scents behind or anything. Keeps my guinea pigs' skin safe and happy",
#      'review_author': '/gp/profile/amzn1.account.AFMCMMMYW476YKSYG3MCQPR53LKQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 6, 14, 0, 0),
#      'review_body': 'Great product. Works well for me in cold water too. Only detergent I use. I use it to refill a smaller bottle.',
#      'review_author': '/gp/profile/amzn1.account.AHGFGRBSA5R57AAVRAIZKKQYMGWQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 8, 16, 0, 0),
#      'review_body': 'Great for babies and those with sensitive skin.  We have had no issues with this soap it and works just as good as "Regular" tide.  Less of a scent, and gentle on skin',
#      'review_author': '/gp/profile/amzn1.account.AFUWNBODOR5TD5IT5NMTBHOZNYQA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 5, 8, 0, 0),
#      'review_body': "Really? It soap.Wife is crazy for smells. Or in this case... no smells.Cleans cloths, doesn't smell.Perfect purchase.",
#      'review_author': '/gp/profile/amzn1.account.AHPDEBB5OZTJU3SBXWEJV5RYN7BQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 12, 1, 0, 0),
#      'review_body': 'Thisbis my favorite laundry soap. Works as same as store bought. Seems th have same consistency',
#      'review_author': '/gp/profile/amzn1.account.AFYDZC5S6S2L22WUN44CKESA54OQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 4, 22, 0, 0),
#      'review_body': 'Again, hard to beat a Tide product.  Since going "unscented", very happy to find Tide "unscented products"',
#      'review_author': '/gp/profile/amzn1.account.AHLOYPIF7A4C3P4OJB2YI5QCMNEA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 6, 5, 0, 0),
#      'review_body': 'Fantastatic No Skin reactions anymore ... I love my Tide F and G HE',
#      'review_author': '/gp/profile/amzn1.account.AHZS5KNAHPERXZLMOLZ76OGPTKXA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 2, 21, 0, 0),
#      'review_body': 'Excellent! Good for families with sensitivities to perfumes etc.',
#      'review_author': '/gp/profile/amzn1.account.AEVBNNPTPHTAWOQ2V7NVEQB25T5Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 9, 24, 0, 0),
#      'review_body': 'I have a baby so I am glad to use this product and not have any affects on her sensitive skin',
#      'review_author': '/gp/profile/amzn1.account.AFU5K5D7THAC34CNYRWK4FTIUUAA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 4, 15, 0, 0),
#      'review_body': "Cleans the laundry and doesn't irritate sensitive skin.",
#      'review_author': '/gp/profile/amzn1.account.AHZQCV72Z5AA3HQCXV6DUSD2R7CA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 3, 16, 0, 0),
#      'review_body': 'very happy with this product. i will buy it again.',
#      'review_author': '/gp/profile/amzn1.account.AEDAUMKGV3TN577CQOMZKCNGBXYQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 5, 15, 0, 0),
#      'review_body': "I'm glad I went to liquid laundry detergent.  Good product which does the job.",
#      'review_author': '/gp/profile/amzn1.account.AEV44IB6YIQCTRYSKH4MYFHBK52A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 6, 14, 0, 0),
#      'review_body': 'Wonderful clear and clean.',
#      'review_author': '/gp/profile/amzn1.account.AHUJGRRQQXNSOHGW5WOOUXUFVZSA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 1, 11, 0, 0),
#      'review_body': "i'm allergic to something in regular tide. probably colour or fragrance. this one washes just as good but doesn't irritate my skin.",
#      'review_author': '/gp/profile/amzn1.account.AFJQMMCYBHMHMLJ2E2OZZW37UIRA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 11, 15, 0, 0),
#      'review_body': 'Cost effectiveAlso less footprint because you don’t have to order as often',
#      'review_author': '/gp/profile/amzn1.account.AH75LW344T5YHAMV7Y7HZNZWWUPQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 6, 3, 0, 0),
#      'review_body': 'great',
#      'review_author': '/gp/profile/amzn1.account.AFSMXBF4NBPHMJUBVKPXNQPFC6MQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 3, 29, 0, 0),
#      'review_body': 'Leaked in the box.',
#      'review_author': '/gp/profile/amzn1.account.AH4PURBDF46A7YJU4D4KV2ZZCOGQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 10, 8, 0, 0),
#      'review_body': 'My wife has used this product for sometime and it is a very nice product to work with.',
#      'review_author': '/gp/profile/amzn1.account.AGLZOABDGPN3ZHCFKQ6YGNGRCFOQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 3, 20, 0, 0),
#      'review_body': 'I prefer a bit of scent in my detergent but this does a good job!',
#      'review_author': '/gp/profile/amzn1.account.AEQ3UXP243CNWH3CYG7DOAJ2URKQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 6, 8, 0, 0),
#      'review_body': 'Perfect jug for the front load washing door system.',
#      'review_author': '/gp/profile/amzn1.account.AHPDEBB5OZTJU3SBXWEJV5RYN7BQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 1, 17, 0, 0),
#      'review_body': 'Arrived as described.',
#      'review_author': '/gp/profile/amzn1.account.AGYVLV65WB25CW6NAHZIZPCNWEXA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 1, 31, 0, 0),
#      'review_body': 'As advertised.',
#      'review_author': '/gp/profile/amzn1.account.AHHCWAZ5YBXO3IUZL4DSRUR7QESA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 3, 25, 0, 0),
#      'review_body': 'perfect',
#      'review_author': '/gp/profile/amzn1.account.AECA3ZXW56YGLH24YE2CNLP2WEDA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 11, 10, 0, 0),
#      'review_body': 'Cleans well, next to no scent whatsoever, and good for sensitive skin.',
#      'review_author': '/gp/profile/amzn1.account.AGIS3BYVWHPLGJYFS6G2JYPXDAQQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 3, 20, 0, 0),
#      'review_body': 'Great product.',
#      'review_author': '/gp/profile/amzn1.account.AGVNSPZ35KI5UEBPYY55AB3Q3YSQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 18, 0, 0),
#      'review_body': 'C$14.10 after subscription and $2 coupon.',
#      'review_author': '/gp/profile/amzn1.account.AGYOYIKFSTAKBYD24VKW77JYWU2Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 4, 14, 0, 0),
#      'review_body': 'Tide is always good!',
#      'review_author': '/gp/profile/amzn1.account.AFBJEIF6GZFXJSTV2YGKFX3WCNWQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 7, 15, 0, 0),
#      'review_body': 'Good stuff.  Less irritating than other detergents.  Compatible with modern washing machines.',
#      'review_author': '/gp/profile/amzn1.account.AGMI7IGC32CFN7EDHWIVTCBXTQSA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 4, 7, 0, 0),
#      'review_body': 'great for baby clothes',
#      'review_author': '/gp/profile/amzn1.account.AFCWGTVROS5IGZV6WDVWWDI3IYUA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 22, 0, 0),
#      'review_body': 'Works great and without any scent.',
#      'review_author': '/gp/profile/amzn1.account.AH7UY2QIEWEU7G6OMRSIUIBFFMYA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 6, 8, 0, 0),
#      'review_body': 'Works great and much better for our skin.',
#      'review_author': '/gp/profile/amzn1.account.AGKEOUC3RLZDOEXHK7VHLXV2VYVQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 2, 21, 0, 0),
#      'review_body': 'excellent',
#      'review_author': '/gp/profile/amzn1.account.AEJS5Y4OW2S4MRIXMVBGE6BTZILQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 10, 6, 0, 0),
#      'review_body': 'No irritation for me or baby and we both have very sensitive skin.',
#      'review_author': '/gp/profile/amzn1.account.AHCNPTLT4RS5JSDSRSHJZZTM7QLQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 3, 0, 0),
#      'review_body': 'good price',
#      'review_author': '/gp/profile/amzn1.account.AFIXCGW7UXP6QWROVMT65KSUWLCA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 8, 3, 0, 0),
#      'review_body': "It's an affordable detergent to wash babys clothes and cloth diepers. I find that other detergents leave babys skin red.",
#      'review_author': '/gp/profile/amzn1.account.AFK56MPLT6NAG7FUK2Q23FBDTWKA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 11, 21, 0, 0),
#      'review_body': 'excellent',
#      'review_author': '/gp/profile/amzn1.account.AEJS5Y4OW2S4MRIXMVBGE6BTZILQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 10, 15, 0, 0),
#      'review_body': 'A+ product!',
#      'review_author': '/gp/profile/amzn1.account.AFJAT4BOOKPCLNXOPX7NSEQLBLMQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 2, 5, 0, 0),
#      'review_body': 'great price and delivered to my home',
#      'review_author': '/gp/profile/amzn1.account.AFS5JTJ7RHOQ2UFQAMJOTI5WGEEA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 12, 1, 0, 0),
#      'review_body': 'My favorite detergent.',
#      'review_author': '/gp/profile/amzn1.account.AEDF7OIAZPHRK7KEFROWQO6O5SGQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 12, 30, 0, 0),
#      'review_body': 'good product.',
#      'review_author': '/gp/profile/amzn1.account.AEIXI4KH26V6HQ44M7MZTJNMGLCQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 10, 24, 0, 0),
#      'review_body': 'Love it, but I will have to buy @ the store!!! No S& H CHRGS.',
#      'review_author': '/gp/profile/amzn1.account.AFFHKPEJYHRQI4BR4VOOOXFJ7TWQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 3, 8, 0, 0),
#      'review_body': 'I like it',
#      'review_author': '/gp/profile/amzn1.account.AE3ZFNEP7NJIW7ZX5NDLVNIAM6XA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 4, 7, 0, 0),
#      'review_body': 'thanks',
#      'review_author': '/gp/profile/amzn1.account.AHLPX4BE7ECU7HI7PVZDCPBOOCDA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 4, 20, 0, 0),
#      'review_body': 'I have sensitive skin and this works well for me.',
#      'review_author': '/gp/profile/amzn1.account.AETHIS3BIACI45XSXEBZVGTLBARA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 10, 18, 0, 0),
#      'review_body': 'Fast shipping and a good price... I will buy again',
#      'review_author': '/gp/profile/amzn1.account.AF4L3SLFFLQLKNSRMDDMVGIGJC5A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 4, 13, 0, 0),
#      'review_body': 'With a family that has sensitive skin this is a must have for laundry detergent.',
#      'review_author': '/gp/profile/amzn1.account.AHCBFUG7QVZ5HEE6RY2XASZJPO3Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 2, 6, 0, 0),
#      'review_body': 'Just getting over a terrible case of contact dermatitis after washing my bedding in this. Terrible rash on all exposed skin - ears, sides of face, and neck. Immediately improved after rewashing in another detergent. Thought it would be a good choice for my highly atopic family but I was very wrong. Never using this product again.',
#      'review_author': '/gp/profile/amzn1.account.AHGPTGRZKWYN23RYGS4DRVWMAMJA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 6, 8, 0, 0),
#      'review_body': 'This liquid laundry detergent cleaned my clothes very well and also did not cause any skin irritation. It has a pleasant smell that is not over powering.',
#      'review_author': '/gp/profile/amzn1.account.AGHEPGWRHJSJZITBVP77E7JBCZ3A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 8, 16, 0, 0),
#      'review_body': 'Love the product and live getting it delivered',
#      'review_author': '/gp/profile/amzn1.account.AE6L52TOI5XHF6VRJFP3PKWK4D3Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 7, 0, 0),
#      'review_body': 'Used this to wash baby clothing; safe and clean.',
#      'review_author': '/gp/profile/amzn1.account.AEPCJBKQBYHUQU43PUHKMSN37ZFQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 10, 16, 0, 0),
#      'review_body': "I've used this product for a long time.",
#      'review_author': '/gp/profile/amzn1.account.AHOBGBJGFHQI2WVSNPXBY5GJBT5A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 4, 23, 0, 0),
#      'review_body': "This is the worst laundry detergent I have used aside from regular tide.  While putting my laundry away I would become incredibly fatigued, develop a rash and tremor.  I become ill if near anyone who uses Tide.  No wonder looking at the toxic ingredients.  Don't use this product if you want to protect your family from toxins.",
#      'review_author': '/gp/profile/amzn1.account.AHCIRBEWC3AIKBKNV4BOZUILUMUQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 10, 1, 0, 0),
#      'review_body': 'Good price.',
#      'review_author': '/gp/profile/amzn1.account.AFYUVDAOIFSABHMSHWCQTQ5V3CJQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 10, 20, 0, 0),
#      'review_body': 'Excellent produit',
#      'review_author': '/gp/profile/amzn1.account.AHS76S65JC36YX4M3CTBP7FV4FWQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 2, 0, 0),
#      'review_body': "My wife checked all the other options and came back to Tide. It does the job well and is about as environmentally friendly a product as she has been able to find. This jug is huge and its heavy so we've had to pour some off into a smaller container that she can manage.",
#      'review_author': '/gp/profile/amzn1.account.AGIMXUZPGZPS2ITROVGXXO42B7ZA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 6, 29, 0, 0),
#      'review_body': 'GREAT',
#      'review_author': '/gp/profile/amzn1.account.AG5OYBNQSXOSHNBTGG4KKF2NGSRA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 30, 0, 0),
#      'review_body': 'Been using this for a while. Good for sensitive skin and pet-friendly!',
#      'review_author': '/gp/profile/amzn1.account.AHR6Z4URHK2V72GRNWS5WQIMIC2Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 28, 0, 0),
#      'review_body': 'It’s ok.',
#      'review_author': '/gp/profile/amzn1.account.AGIYXCP5WV6SEKCAGIRXU3FGKZVA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 28, 0, 0),
#      'review_body': "I thought I would try this unscented detergent.Upon using it for a while, I find that I miss the regular one with some scent.I think this Tide Free still washes clothes just as good though.I could recommend it if you don't want any scent in your wash.",
#      'review_author': '/gp/profile/amzn1.account.AFQQKTTTB7UJM72XH4OF72RALYPA/ref=cm_cr_arp_d_pdp?ie=UTF8'}]},
#   'details': {'price': '17.88',
#    'name': 'Tide Free and Gentle HE Liquid Laundry Detergent, Unscented, 4.43 L (96 Loads)'}},
#  'walmart': [{'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '49.895849,-97.195621',
#     'storeCustomMessage': '',
#     'storeId': '3116',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 25,
#        'maxRegularPrice': 25,
#        'minCurrentPrice': 9.93,
#        'maxCurrentPrice': 9.93,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'Available',
#        'storeNumber': '3116',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'Available',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': False,
#       'minRegularPrice': 25,
#       'maxRegularPrice': 25,
#       'minCurrentPrice': 9.93,
#       'maxCurrentPrice': 9.93}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '50.496571,-104.637024',
#     'storeCustomMessage': '',
#     'storeId': '3076',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 25,
#        'maxRegularPrice': 25,
#        'minCurrentPrice': 9.93,
#        'maxCurrentPrice': 9.93,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'Available',
#        'storeNumber': '3076',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'Available',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': False,
#       'minRegularPrice': 25,
#       'maxRegularPrice': 25,
#       'minCurrentPrice': 9.93,
#       'maxCurrentPrice': 9.93}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '43.668635,-79.338302',
#     'storeCustomMessage': '',
#     'storeId': '1150',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 25,
#        'maxRegularPrice': 25,
#        'minCurrentPrice': 9.93,
#        'maxCurrentPrice': 9.93,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'OutOfStock',
#        'storeNumber': '1150',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'OutOfStock',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 25,
#       'maxRegularPrice': 25,
#       'minCurrentPrice': 9.93,
#       'maxCurrentPrice': 9.93}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '45.502980,-73.637075',
#     'storeCustomMessage': '',
#     'storeId': '1170',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 20,
#        'maxRegularPrice': 20,
#        'minCurrentPrice': 9.93,
#        'maxCurrentPrice': 9.93,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'Available',
#        'storeNumber': '1170',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'Available',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': False,
#       'minRegularPrice': 20,
#       'maxRegularPrice': 20,
#       'minCurrentPrice': 9.93,
#       'maxCurrentPrice': 9.93}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '44.647284,-63.619071',
#     'storeCustomMessage': '',
#     'storeId': '3636',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 25,
#        'maxRegularPrice': 25,
#        'minCurrentPrice': 9.93,
#        'maxCurrentPrice': 9.93,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'Available',
#        'storeNumber': '3636',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'Available',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': False,
#       'minRegularPrice': 25,
#       'maxRegularPrice': 25,
#       'minCurrentPrice': 9.93,
#       'maxCurrentPrice': 9.93}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '45.986020,-66.627044',
#     'storeCustomMessage': '',
#     'storeId': '1067',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 25,
#        'maxRegularPrice': 25,
#        'minCurrentPrice': 9.93,
#        'maxCurrentPrice': 9.93,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'Available',
#        'storeNumber': '1067',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'Available',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': False,
#       'minRegularPrice': 25,
#       'maxRegularPrice': 25,
#       'minCurrentPrice': 9.93,
#       'maxCurrentPrice': 9.93}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '47.532781,-52.751715',
#     'storeCustomMessage': '',
#     'storeId': '1179',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 25,
#        'maxRegularPrice': 25,
#        'minCurrentPrice': 9.93,
#        'maxCurrentPrice': 9.93,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'OutOfStock',
#        'storeNumber': '1179',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'OutOfStock',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 25,
#       'maxRegularPrice': 25,
#       'minCurrentPrice': 9.93,
#       'maxCurrentPrice': 9.93}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '46.262392,-63.152691',
#     'storeCustomMessage': '',
#     'storeId': '3162',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 20,
#        'maxRegularPrice': 20,
#        'minCurrentPrice': 9.93,
#        'maxCurrentPrice': 9.93,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'Available',
#        'storeNumber': '3162',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'Available',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': False,
#       'minRegularPrice': 20,
#       'maxRegularPrice': 20,
#       'minCurrentPrice': 9.93,
#       'maxCurrentPrice': 9.93}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '53.538011,-113.420372',
#     'storeCustomMessage': '',
#     'storeId': '3026',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 25,
#        'maxRegularPrice': 25,
#        'minCurrentPrice': 9.93,
#        'maxCurrentPrice': 9.93,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'OutOfStock',
#        'storeNumber': '3026',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'OutOfStock',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 25,
#       'maxRegularPrice': 25,
#       'minCurrentPrice': 9.93,
#       'maxCurrentPrice': 9.93}}}},
#   {'store': {'storeNumber': '0',
#     'myStore': True,
#     'name': '',
#     'mainIntersection': '',
#     'city': '',
#     'province': '',
#     'url': '/en//0',
#     'badges': [],
#     'storeLocation': '49.259280,-123.027429',
#     'storeCustomMessage': '',
#     'storeId': '1104',
#     'storeAddress': '',
#     'storeHours': [''],
#     'storeFormattedHours': [],
#     'storeTimeZone': '',
#     'storePhoneNumber': '',
#     'storeServices': [],
#     'storePostalCode': '',
#     'storeHolidaysHours': [],
#     'storeOpenDate': ''},
#    'details': {'p': {'online': [],
#      'stores': [{'minRegularPrice': 25,
#        'maxRegularPrice': 25,
#        'minCurrentPrice': 9.93,
#        'maxCurrentPrice': 9.93,
#        'sku': '',
#        'clearance': False,
#        'limited': False,
#        'limitedStock': False,
#        'rollback': False,
#        'date': '',
#        'status': 'OutOfStock',
#        'storeNumber': '1104',
#        'eligible': False,
#        'asAdvertised': False}],
#      'storeSummary': {'status': 'OutOfStock',
#       'date': '',
#       'eligible': False,
#       'clearance': False,
#       'rollback': False,
#       'asAdvertised': False,
#       'limited': False,
#       'limitedStock': True,
#       'minRegularPrice': 25,
#       'maxRegularPrice': 25,
#       'minCurrentPrice': 9.93,
#       'maxCurrentPrice': 9.93}}}}]}
