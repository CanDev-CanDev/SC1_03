# %%
import requests
from bs4 import BeautifulSoup as bs
from datetime import datetime
import re
import pickle

# %%
class AmazonDataFetcher:
    def __init__(self, session, BASE_URL, default_parser):
        self.session = session
        self.BASE_URL = BASE_URL
        self.DEFAULT_PARSER = default_parser
        self.PRODUCT_REVIEWS = "%s/product-reviews" % self.BASE_URL
        self.PRODUCT_PAGE = "%s/dp" % (self.BASE_URL)
        self.price_pat = r'CDN\$ ([0-9.]+)'
        
    def convert_price(self, price_string):
        return re.findall(self.price_pat, price_string)[0]
        
    def parse_product_page(self, page_content):
        souped = bs(page_content, self.DEFAULT_PARSER)
        return {
            "price": self.convert_price(souped.find("span", {"id": "priceblock_ourprice"}).text),
            "name": souped.find("span", {"id": "productTitle"}).text.strip()
        }
        
    def fetch_product_page(self, URL):
        req = self.session.get(URL)
        return self.parse_product_page(req.content)
        
    def fetch_product_page_from_id(self, product_id):
        return self.fetch_product_page("%s/%s" % (self.PRODUCT_PAGE, product_id,))
        
    def convert_date(self, date_string):
        return datetime.strptime(date_string, "on %B %d, %Y")
        
    def parse_review_box(self, review_box):
        return {
            "review_date": self.convert_date(review_box.find("span", {"data-hook": "review-date"}).text),
            "review_body": review_box.find("span", {"data-hook": "review-body"}).text,
            "review_author": review_box.find("a", {"data-hook": "review-author"})["href"]
        }
        
        
    def parse_page_content(self, page_content):
        souped = bs(page_content, self.DEFAULT_PARSER)
        review_box = souped.find("div", {"id": "cm_cr-review_list"})
        review_boxes = review_box.find_all("div", {"class": "review"})
        next_button = souped.find("li", {"class": "a-last"}).find("a")
        return {
            "reviews": [self.parse_review_box(x) for x in review_boxes],
            "next_page": next_button["href"] if next_button else None
        }
        
        
    def fetch_reviews_from_id(self, product_id):
        req = self.session.get("%s/%s" % (self.PRODUCT_REVIEWS, product_id,))
        return self.parse_page_content(req.content)
        
    def fetch_reviews_on_page(self, URL):
        req = self.session.get(URL)
        return self.parse_page_content(req.content)
    
    def fetch_all_reviews_from_id(self, product_id, max_pages = -1):
        return self.fetch_all_reviews("%s/%s" % (self.PRODUCT_REVIEWS, product_id))
    
    def fetch_all_reviews(self, URL, max_pages=-1):
        url = URL
        reviews = []
        pages = 0
        while (url and pages != max_pages):
            pages += 1
            data = self.fetch_reviews_on_page(url)
            reviews += data["reviews"]
            if (not data["next_page"]):
                break
                
            url = "%s%s" % (self.BASE_URL,data["next_page"],)
        return {
            "reviews": reviews
        }
    
    def fetch_all_data_from_id(self, product_id):
        return {
            "reviews": self.fetch_all_reviews_from_id(product_id),
            "details": self.fetch_product_page_from_id(product_id)
        }

# %%
class WalmartDataFetcher:
    def __init__(self, session):
        self.session = session
        self.BASE_URL = "https://stock.ga/wm"
        self.NEAREST_STORE_URL = "%s/nearest-store.php" % (self.BASE_URL)
        self.AVAILABILITY_URL = "%s/availability.php" % (self.BASE_URL)
        self.SEARCH_URL = "%s/search.php" % (self.BASE_URL)
        
    def fetch_availability(self, upc, storeId):
        req = self.session.get(
            self.AVAILABILITY_URL,
            params = {
                "storeId": storeId,
                "upc": upc,
                "src": "upc"
            }
        )
        return req.json()
    
    def fetch_availability_multi_store(self, upc, stores):
        return [{
            "store": store,
            "details": self.fetch_availability(upc, store.get("storeId"))
        } for store in stores]
    
    def fetch_nearest_store(self, lon, lat, numstores=1):
        req = self.session.get(
            self.NEAREST_STORE_URL, 
            params = {
                "numstores": numstores, 
                "lattitude": lat, 
                "longitude": lon, 
                "showpickuplocation": "false",
                "mystore": ""
            })
        
        return req.json()
    
    def fetch_all_nearest_stores(self, coordinates):
        return [self.fetch_nearest_store(coords["lon"], coords["lat"]) for coords in coordinates]
    
    def parse_search_results(self, search_results):
        return search_results.get("result")[0].get("sku")
    
    
    def fetch_search_and_data(self, query, stores):
        return self.fetch_availability_multi_store(
            self.parse_search_results(self.fetch_search_results(query)),
            stores
        )
    
    def fetch_search_results(self, query):
        req = self.session.get(
            self.SEARCH_URL,
            params = {
                "q": query,
                "n": "60",
                "p": "1"
            }
        )
        
        return req.json()

# %% [markdown]
# #### Parsing text into proper format

# %%
pat = r'(.*), Canada\nLatitude: ([0-9.\-]+) \| Longitude: ([0-9.\-]+)'
data = '''
Winnipeg, MB R3B 1B9, Canada
Latitude: 49.899861 | Longitude: -97.139199
Regina, SK S4P 3C8, Canada
Latitude: 50.451903 | Longitude: -104.614313
Toronto, ON M5H 2N2, Canada
Latitude: 43.652549 | Longitude: -79.383512
Montreal, QC H2Y 1C6, Canada
Latitude: 45.508848 | Longitude: -73.554642
Halifax, NS B3J 3A5, Canada
Latitude: 44.64747 | Longitude: -63.572177
Fredericton, NB E3B 1B5, Canada
Latitude: 45.963394 | Longitude: -66.643218
St. John’s, NL A1C 1J3, Canada
Latitude: 47.560938 | Longitude: -52.713105
Charlottetown, PE C1A 4B7, Canada
Latitude: 46.235603 | Longitude: -63.12992
Edmonton, AB T5J 3E9, Canada
Latitude: 53.544979 | Longitude: -113.49349
Vancouver, BC V5Y 1V4, Canada
Latitude: 49.261057 | Longitude: -123.114077
'''

data = re.findall(pat, data)

# %%
stores = [
    {
        "location": x[0],
        "lat": x[1],
        "lon": x[2]
    } for x in data
]

# %%
all_store_details = walmartDataFetcher.fetch_all_nearest_stores(stores)

# %% [markdown]
# ### Sanatize data

# %%
all_store_details = [x.get("stores")[0] for x in all_store_details]

# %%
class Main:
    def __init__(self, all_stores):
        self.session = requests.Session()
        self.session.headers.update({"user-agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.67 Safari/537.36"})
        self.walmartDataFetcher = WalmartDataFetcher(session)
        self.amazonDataFetcher = AmazonDataFetcher(session, "https://amazon.ca", "lxml")
        self.all_store_details = all_stores
        
    def fetch_product_info_by_id(amazonId, walmartId):
        return {
            "amazon": self.amazonDataFetcher.fetch_all_data_from_id(amazonId),
            "walmart": self.walmartDataFetcher.fetch_availability_multi_store(walmartId, all_store_details)
        }
    
    def fetch_product_info_by_amazonId(self, amazonId):
        data = {
            "amazon": self.amazonDataFetcher.fetch_all_data_from_id(amazonId)
        }
        
        data["walmart"]: self.walmartDataFetcher.fetch_search_and_data(data["amazon"].get("name"))
            
            
        return data

# %%
main = Main(all_store_details)

# %%
main.fetch_product_info_by_amazonId("B004QEE2PU")
# Out:
# {'amazon': {'reviews': {'reviews': [{'review_date': datetime.datetime(2016, 10, 20, 0, 0),
#      'review_body': "This brand of Tide is our favorite. It's good on the clothes, doesn't leave too much scent, and cleans very well. It works well with High Efficiency washers and we've been using it for a couple of years now.We get it through subscribe and save (5% discount) and whenever we run out, there's always the option of same day delivery which is awesome. However, I just switched to the 4.4 liter size today since it has a nice dispenser.Tide Original Scent HE Turbo Clean Liquid Laundry Detergent, 4.43 Litre, 96 loadsDefinitely recommended.",
#      'review_author': '/gp/profile/amzn1.account.AG6FE26A6QZB2RVOCXBDNE7PCWYA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 10, 15, 0, 0),
#      'review_body': "I always use tide and with this price, you can't go wrong. Excellent. No need to go to the store to buy, i am very siensitive with scent so its  perfect for me. No need to to detergent isle. Bonus, free deliveries. We'll buy again.",
#      'review_author': '/gp/profile/amzn1.account.AHZZ7JOK6TN3K5BPI4WIIX4D2HXA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 11, 26, 0, 0),
#      'review_body': 'I find that original scent Tide keeps my clothes smelling fresh even without the use of fabric softeners or other "scent packs".Since switching to Tide from the cheaper grocery store brands years ago, I\'ve found that my clothes don\'t seem to fade/discolour the way they used to.When on sale, Amazon has the best price per litre that I can find.',
#      'review_author': '/gp/profile/amzn1.account.AFZAAEPZQHFOQUTKQLBIL6UTW5SQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 10, 15, 0, 0),
#      'review_body': 'I had gone with an "eco" brand of detergent for a while but some of our clothes kept coming out stained... when I switched back to tide we saw improvements on the cleanliness of clothes, even the ones we thought weren\'t going to be cleaner again.',
#      'review_author': '/gp/profile/amzn1.account.AEVZZH2QX3LMKYT4AFLCV2KEL55A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 7, 3, 0, 0),
#      'review_body': 'So much better than some of those other brands.  Does not destroy your clothing like the sunny lemon stuff.  Tide is far superior.',
#      'review_author': '/gp/profile/amzn1.account.AHQXUKDI4AY4XCDACTPGQHPUMSKA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 10, 17, 0, 0),
#      'review_body': 'Doesn’t have one of those fancy caps that you can use to put detergent in and put it back without worrying about it leaking everywhere. But it’s a lot of soap for a pretty good price. Can’t go wrong',
#      'review_author': '/gp/profile/amzn1.account.AE45UAYR3TXSG6QNTX3K6GCYK55Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 7, 23, 0, 0),
#      'review_body': "Tide detergent is the only laundry detergent I will use. It isn't hard on my clothes, makes them smell fresh, and most importantly, gets them clean. Amazon sells it for a very competitive price and delivers it right to my door. I use Subscribe and Save and I never have to think about running out. Thanks Amazon!",
#      'review_author': '/gp/profile/amzn1.account.AHHTXBO2VXQHX3NIBMKKFLTPXVRQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 2, 5, 0, 0),
#      'review_body': 'This works great for my front load HE washer. I have noticed a big difference in how clean my clothes are getting vs. when I used regular detergents. I had some itchy skin after using this initially, but now I am a lot more used to it.',
#      'review_author': '/gp/profile/amzn1.account.AEXM4YZ5POXIX5W4WWUIQQSYBYEQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 6, 0, 0),
#      'review_body': "Tide will clean your clothes without fading the color. This is the best price for this product, so it's worth the investment for  keeping your clothes in excellent condition.",
#      'review_author': '/gp/profile/amzn1.account.AFDSM74MQ5O2UBISEL634LSKYJBQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 10, 20, 0, 0),
#      'review_body': "The container is not as heavy as I thought it would be and easy too use, cleans clothing better and doesn't cause rashes for me.",
#      'review_author': '/gp/profile/amzn1.account.AENWAEONKWYHJURGAWVC45QP74LQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 2, 26, 0, 0),
#      'review_body': 'Nice detergent for cleaning, it smells so good and it cleans the most harder stains on the clothes, I really recommend to the people to buy this product.',
#      'review_author': '/gp/profile/amzn1.account.AGZBYARL4KH5HHABHM3Q5WLZJPJA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 2, 21, 0, 0),
#      'review_body': 'Excellent. Don’t buy cheap detergents. You save on the cost of the detergent but you’ll be washing twice.',
#      'review_author': '/gp/profile/amzn1.account.AEVBNNPTPHTAWOQ2V7NVEQB25T5Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 5, 30, 0, 0),
#      'review_body': 'Keeps my laundry clean. Will continue to use this until something incredible appears before me',
#      'review_author': '/gp/profile/amzn1.account.AFQLSDB5WXIQLJZZKASFZVVHHHLQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 2, 19, 0, 0),
#      'review_body': 'Excellent product but item arrived without the cap for measuring and dispensing. This is why only 3 stars. Luckily I had an old bottle on hand with a cap still or I would have went it back. Please be more cautious when shipping.',
#      'review_author': '/gp/profile/amzn1.account.AH2KS2IDYORNE4EMUJIMLA3PYWOQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 6, 14, 0, 0),
#      'review_body': 'good price for this size jug. Even better on subscribe and save.',
#      'review_author': '/gp/profile/amzn1.account.AFSRWVU2K2DS6STUODMZNYYSLSKQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 5, 15, 0, 0),
#      'review_body': 'Product is great... 5 starsDelivery not so much... product leaked. Looks like top collar popped open.Everything else was sticky with Tide.All smelled great though.I have had it delivered before with no issues.',
#      'review_author': '/gp/profile/amzn1.account.AGN2UZNIKYR5X37IZ3VZAHVU2S6Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 1, 25, 0, 0),
#      'review_body': "I have used the same product for many years. Whatever is the load's size, don't use more than small amount of soap ( first line in the measuring cup that come with the product).",
#      'review_author': '/gp/profile/amzn1.account.AFCBCM5IICU4OC66RNUKSTPSOYCQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 6, 12, 0, 0),
#      'review_body': 'this is all that goes into my washing machine',
#      'review_author': '/gp/profile/amzn1.account.AGD6A2F57UO5FFEXUWIM4BEBFJOQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 2, 16, 0, 0),
#      'review_body': 'Have been a happy tide laundry detergent user for long time and have not looked at other products.  This is for me.',
#      'review_author': '/gp/profile/amzn1.account.AH5NDGRNQUFKLR3JX6EKFJPDJMJQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 10, 15, 0, 0),
#      'review_body': 'Always been my favourite. Always will be',
#      'review_author': '/gp/profile/amzn1.account.AGD46PWRTALOHO2B7BFWV3IJGLGA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 10, 15, 0, 0),
#      'review_body': 'Good price and good product.',
#      'review_author': '/gp/profile/amzn1.account.AGQD4YJHQVIGYCPKWKH4EUXTXBLQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 3, 17, 0, 0),
#      'review_body': 'It is TIDE so of course it is perfect.',
#      'review_author': '/gp/profile/amzn1.account.AHEUFCCZ5P74YFRYTM6NVYOQYFWQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 3, 10, 0, 0),
#      'review_body': 'A product I have been using for many years, and am very satisfied with the results of its use',
#      'review_author': '/gp/profile/amzn1.account.AGHTIZNUR5XHDYU2B7W47EBQ673Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 10, 3, 0, 0),
#      'review_body': 'Love my tide reasonable price',
#      'review_author': '/gp/profile/amzn1.account.AGYM3C4WSGM4VZB5WQV32AW6AA3Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 6, 25, 0, 0),
#      'review_body': 'the only one I can use',
#      'review_author': '/gp/profile/amzn1.account.AEGISYERR5JZ6Z7BZS6WW7YCCDWA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 8, 24, 0, 0),
#      'review_body': 'Love the original scent. Cleans well.',
#      'review_author': '/gp/profile/amzn1.account.AEVFC2ES7EHCDAT6RS7Z3SORWQZA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 7, 16, 0, 0),
#      'review_body': 'Exactly as pictured - just what we needed!',
#      'review_author': '/gp/profile/amzn1.account.AHT3HFDPBJVGCQLKBRV6PIKP26RQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 23, 0, 0),
#      'review_body': 'bought before',
#      'review_author': '/gp/profile/amzn1.account.AGIDMJIBQPNJILVGNGJMOLY2QFIA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 6, 10, 0, 0),
#      'review_body': 'Just what I wanted',
#      'review_author': '/gp/profile/amzn1.account.AEHA73PYG6IQOXC76OEDVER7SDYQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 2, 25, 0, 0),
#      'review_body': 'Great product at a great price!',
#      'review_author': '/gp/profile/amzn1.account.AE4B4T5PO27EX65S25BAZMDDJMWQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 5, 26, 0, 0),
#      'review_body': "I'll keep buying at this price",
#      'review_author': '/gp/profile/amzn1.account.AEOQPR34XRZUBJLBFUWV2SAZ34WQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 9, 19, 0, 0),
#      'review_body': "C'est mon produit préféré.",
#      'review_author': '/gp/profile/amzn1.account.AEUS4W7NVWBCPXMGXWGYZ2RMN5HQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 8, 20, 0, 0),
#      'review_body': 'Love it',
#      'review_author': '/gp/profile/amzn1.account.AE42WLUGQ2XHTOCFA5WMZ3VP67JQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 17, 0, 0),
#      'review_body': 'Usual standard',
#      'review_author': '/gp/profile/amzn1.account.AEY2NMG7JFWZ4UNTTDNIYW3CVQCA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 6, 21, 0, 0),
#      'review_body': 'Good value, good product.',
#      'review_author': '/gp/profile/amzn1.account.AHBJ3YFYYQ4OHOMUG4A2M6LIKZAQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 8, 1, 0, 0),
#      'review_body': 'Good',
#      'review_author': '/gp/profile/amzn1.account.AFULIQ3PXEEOBHNS46CUW2NFIWBA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 4, 23, 0, 0),
#      'review_body': 'perfect',
#      'review_author': '/gp/profile/amzn1.account.AGD57OYURVDBJ3UPBIYM4MHJJEHQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 4, 7, 0, 0),
#      'review_body': 'Good price with the coupon ... Tide is my #1 brand I use',
#      'review_author': '/gp/profile/amzn1.account.AF6OAY6Y3GV4I77JUCUC3ELFSREQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 3, 28, 0, 0),
#      'review_body': 'cleans better than the bargain  crap',
#      'review_author': '/gp/profile/amzn1.account.AEU6J7V7HMGBRQDMVUO4QCWQASAQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 7, 18, 0, 0),
#      'review_body': 'Très bon produit et livraison rapide',
#      'review_author': '/gp/profile/amzn1.account.AHB6E5YIDM6WHBGPDJ43G6GCOEEA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 7, 19, 0, 0),
#      'review_body': 'great product, fast shipping',
#      'review_author': '/gp/profile/amzn1.account.AF34VRU6AGPUXS25AOZI7WBWTVKA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 4, 10, 0, 0),
#      'review_body': "c'est parfait",
#      'review_author': '/gp/profile/amzn1.account.AEKPYQYMI3JISQ63T5VPFBOIZEHQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 3, 20, 0, 0),
#      'review_body': 'value for money',
#      'review_author': '/gp/profile/amzn1.account.AFQPQODXXTO5ONBZSJAVBY2YPLGQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 10, 11, 0, 0),
#      'review_body': 'just as before it works great',
#      'review_author': '/gp/profile/amzn1.account.AENUURID2FUDGOWYF633E5QRO24Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 5, 18, 0, 0),
#      'review_body': 'Perfect',
#      'review_author': '/gp/profile/amzn1.account.AHMI7LJKZ727DAMZDPE7DONQRCQA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 2, 7, 0, 0),
#      'review_body': 'does the job',
#      'review_author': '/gp/profile/amzn1.account.AH3R5SNSM4T3MNIFR6EGEUP53I5A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 2, 25, 0, 0),
#      'review_body': 'Love the smell.',
#      'review_author': '/gp/profile/amzn1.account.AHMQDJRJITUNGN3VUFYGBXTRFTUQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 8, 2, 0, 0),
#      'review_body': 'Would definitely buy again.',
#      'review_author': '/gp/profile/amzn1.account.AHYGV2NAY2LJEFE5A4YIDFAFUVEA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 5, 22, 0, 0),
#      'review_body': 'good!',
#      'review_author': '/gp/profile/amzn1.account.AFN32SD5RB5CO6ZM7BHJ5LZF2KOA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 1, 25, 0, 0),
#      'review_body': 'Excellent 👍',
#      'review_author': '/gp/profile/amzn1.account.AFD4KUU35GDPVLGD3CPIGPXWYVVA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 6, 0, 0),
#      'review_body': 'Awesome Product',
#      'review_author': '/gp/profile/amzn1.account.AFEY3UEFC4M3AYM6KZ2LQNBK54BQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 1, 20, 0, 0),
#      'review_body': 'Great product, awesome scent.Also much prefer the original Tide over the yellow container basic Tide.Just be sure to always compare prices before buying !!',
#      'review_author': '/gp/profile/amzn1.account.AG6WJZ4J2TABQKW6KPI4NT4UTTIQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 6, 25, 0, 0),
#      'review_body': 'Laundry',
#      'review_author': '/gp/profile/amzn1.account.AH25CEPHYHTB6GJYNWCLR75IQ5AQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 2, 20, 0, 0),
#      'review_body': 'Cleans deep grime and smells heavenly!',
#      'review_author': '/gp/profile/amzn1.account.AFBL23OEFD43YD24L7ZMLCLBHFIQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 7, 5, 0, 0),
#      'review_body': 'I opened the box as soon as i received the package. The lid was broken like that :( now i gotta eyeball how much to put in',
#      'review_author': '/gp/profile/amzn1.account.AG6IZRGRM5AP2VNT7F5DXUVNAUDA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 5, 25, 0, 0),
#      'review_body': 'Used it all my life!',
#      'review_author': '/gp/profile/amzn1.account.AFGX5DRBTKL34UTECQO2PX34BUGA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 11, 15, 0, 0),
#      'review_body': 'works well!',
#      'review_author': '/gp/profile/amzn1.account.AFBQQBXSHDOBK6MGZAQP7GBSXF3A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 12, 20, 0, 0),
#      'review_body': 'Very good item',
#      'review_author': '/gp/profile/amzn1.account.AGTKOWOAKEKFY6RWLOEYLP2J3W5A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 5, 23, 0, 0),
#      'review_body': 'works great, no complaints',
#      'review_author': '/gp/profile/amzn1.account.AFFG3W2VENIJHXM7BADV5XA3BZGA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 10, 1, 0, 0),
#      'review_body': 'Great',
#      'review_author': '/gp/profile/amzn1.account.AG27JFYZVSTT3F6U5BABECJPVZPQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 1, 27, 0, 0),
#      'review_body': 'Great price and next day delivery.',
#      'review_author': '/gp/profile/amzn1.account.AFE2COP3ZPQTIYZKZEQO7WAVDC6Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 3, 19, 0, 0),
#      'review_body': 'This tide has a great smell!!! Makes my laundry smell nice and clean!!!  Also love the bottle shape, very convenient',
#      'review_author': '/gp/profile/amzn1.account.AFV2XGXX5EHYW3CCGMLP25GAZNDQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 11, 0, 0),
#      'review_body': 'Five stars',
#      'review_author': '/gp/profile/amzn1.account.AGJQHXLUJCZZMC4VZ7KZX2WFQQ2Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 9, 23, 0, 0),
#      'review_body': 'Great price!',
#      'review_author': '/gp/profile/amzn1.account.AERTTMUYNDXATSSMDFVUXSYIWOFA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 7, 19, 0, 0),
#      'review_body': 'Tide is always reliable. No complaints here. Happy customer.',
#      'review_author': '/gp/profile/amzn1.account.AG3CQJXUVNKUKONQGOCHPPO2ILXA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 15, 0, 0),
#      'review_body': 'Tide never disappoints!',
#      'review_author': '/gp/profile/amzn1.account.AFCUHNH4IZWJOGJ54Q77P4QFKDQA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 2, 3, 0, 0),
#      'review_body': 'Great Product !',
#      'review_author': '/gp/profile/amzn1.account.AHA7VGFPQNKFJKJY4TMLZD6JUTWA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 11, 18, 0, 0),
#      'review_body': "It wasn't closed properly,  it was leaking.  They  sent it together with diapers,  the box was all wet and smelly",
#      'review_author': '/gp/profile/amzn1.account.AHVA7FXOJBJMCJFTGHVH24F26XBA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 1, 15, 0, 0),
#      'review_body': "It's just laundry detergent .... arrived on time and undamaged as expected.",
#      'review_author': '/gp/profile/amzn1.account.AG34NP2ZMACB3P5LL3RYDXSPYVQA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 2, 0, 0),
#      'review_body': 'Item exactly as described. Very heavy.',
#      'review_author': '/gp/profile/amzn1.account.AEHRUCVISXI3JGOW5G4WMDEP3QUQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 1, 20, 0, 0),
#      'review_body': 'Great stuff',
#      'review_author': '/gp/profile/amzn1.account.AEO3XUYDGBFPQYAUMIDNAHGADMEA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 2, 9, 0, 0),
#      'review_body': 'Wonderful!',
#      'review_author': '/gp/profile/amzn1.account.AEMZSM3A742QI26DGYW5DPK322QA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 1, 1, 0, 0),
#      'review_body': 'great',
#      'review_author': '/gp/profile/amzn1.account.AEMVPH2LZHJRZR4336FH4HPIRD2Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 10, 22, 0, 0),
#      'review_body': 'Great product but no cheaper than in supermarket.',
#      'review_author': '/gp/profile/amzn1.account.AGDT3ONISC4MSLKKNDYAYUFLTIYA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 1, 0, 0),
#      'review_body': 'good',
#      'review_author': '/gp/profile/amzn1.account.AF4UEHYITPI55U5X7OWF35EQ5QRQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 7, 18, 0, 0),
#      'review_body': 'Excellent',
#      'review_author': '/gp/profile/amzn1.account.AGIAVU6U57XKIUED4URYM324Y7GA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 1, 13, 0, 0),
#      'review_body': 'Ok',
#      'review_author': '/gp/profile/amzn1.account.AHK3W66YNBW3PBU4JCKSFGJHXENQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 8, 2, 0, 0),
#      'review_body': 'Arrived without any spillage.',
#      'review_author': '/gp/profile/amzn1.account.AEJKYSKKYG3G3PLHC5S5R354XPPQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 30, 0, 0),
#      'review_body': 'Great product',
#      'review_author': '/gp/profile/amzn1.account.AF5QPJU6HV7HAT435Z7T6MYWN4MA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 3, 5, 0, 0),
#      'review_body': 'Great product & home delivery --- So convenient!!',
#      'review_author': '/gp/profile/amzn1.account.AHGJRZN2GGJNAVSSGXU456MK32PA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 1, 17, 0, 0),
#      'review_body': 'Smaller than I thought it would be, but then again, I get what I pay for.',
#      'review_author': '/gp/profile/amzn1.account.AE2BQ3AQ7K7GNTMHPXLBQ6D3WL4Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 2, 22, 0, 0),
#      'review_body': 'Perfect love the price',
#      'review_author': '/gp/profile/amzn1.account.AFP3O2YCKFJVWDMQVCLHMRDR7S5Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 2, 9, 0, 0),
#      'review_body': 'my usual brand.',
#      'review_author': '/gp/profile/amzn1.account.AEARNFEYOBKDKH4WHDUCKZCWMRQQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 5, 18, 0, 0),
#      'review_body': 'good',
#      'review_author': '/gp/profile/amzn1.account.AE72RMSHNEH334W5DFIG44UNDJIA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 5, 17, 0, 0),
#      'review_body': 'You cant go wrong with tide :)',
#      'review_author': '/gp/profile/amzn1.account.AHRA5SRVNKRUI2UMKEPXGVXWRVGQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 5, 0, 0),
#      'review_body': "Definitely, it's worth the price!",
#      'review_author': '/gp/profile/amzn1.account.AGTY2KHQFMXEPNGO7D2ESY32FNLA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 27, 0, 0),
#      'review_body': 'Excellent！',
#      'review_author': '/gp/profile/amzn1.account.AG3GZZEZ637X5VPHIABHHZLV5V4Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 10, 26, 0, 0),
#      'review_body': 'verrygood wahs sosp',
#      'review_author': '/gp/profile/amzn1.account.AG74VOCZ272HCKW2KOIFXT6RYL2A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 10, 3, 0, 0),
#      'review_body': 'Great as always!',
#      'review_author': '/gp/profile/amzn1.account.AGDCL7HXXRDLBNVQTHFBI5EUZSYA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 9, 4, 0, 0),
#      'review_body': 'C’est tide!',
#      'review_author': '/gp/profile/amzn1.account.AEBRINUM5EFMVRLSZMVRUEMA5KPQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 2, 20, 0, 0),
#      'review_body': 'Good work , but products is bit expensive than Walmart',
#      'review_author': '/gp/profile/amzn1.account.AHMBHBFY3JFUP6WFD27CRUWPB2LQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 8, 19, 0, 0),
#      'review_body': 'Great value and more convenient than going to a store and carrying it home.',
#      'review_author': '/gp/profile/amzn1.account.AG573I6DWJZXL54MYEZ36IY764OA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 10, 11, 0, 0),
#      'review_body': 'its tide',
#      'review_author': '/gp/profile/amzn1.account.AG6F2JD4UEP65TCWKGASLHSNVZRA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 8, 26, 0, 0),
#      'review_body': 'Its fine.',
#      'review_author': '/gp/profile/amzn1.account.AG5RKUQ454BECSHPZOYH2ICGNWUQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 9, 1, 0, 0),
#      'review_body': 'great',
#      'review_author': '/gp/profile/amzn1.account.AFZ2NIVRLG72A4WRTEXRDSUZ4MIA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 1, 29, 0, 0),
#      'review_body': 'Good',
#      'review_author': '/gp/profile/amzn1.account.AHNLHLEP2RITLKDKCUIPDILMZOWQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 11, 29, 0, 0),
#      'review_body': 'Best value for money!',
#      'review_author': '/gp/profile/amzn1.account.AETXZIUS7WECSZKDDHXO3TSEY4LQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 10, 25, 0, 0),
#      'review_body': 'it is too big and not convenient to use.',
#      'review_author': '/gp/profile/amzn1.account.AGTI36VMW4FQZPHSKIFKZYNE4ISQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 4, 18, 0, 0),
#      'review_body': 'This product is great.',
#      'review_author': '/gp/profile/amzn1.account.AFYMZAWGCDTK7BWXI5KP5VXQFZHQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 4, 19, 0, 0),
#      'review_body': 'we can say the  same thing  as we  did for the FINISH....',
#      'review_author': '/gp/profile/amzn1.account.AE6TRWZCLWN2IKB5VN2QQOGPVNGA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 7, 30, 0, 0),
#      'review_body': 'l det is l det',
#      'review_author': '/gp/profile/amzn1.account.AHQ4YQXKGGTQJAS3WVX6NKLDR4HQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2015, 10, 10, 0, 0),
#      'review_body': "It's worth its price.",
#      'review_author': '/gp/profile/amzn1.account.AFHITM2VS34RPRR3KSTVGQRGXXVQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 8, 13, 0, 0),
#      'review_body': '味道good',
#      'review_author': '/gp/profile/amzn1.account.AHBCJVH6J7OF7VFOSBSFSC447ELQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 4, 7, 0, 0),
#      'review_body': 'We have been using this same liquid detergent for almost 9 years now and is our favourite product. We have tried many other products in between, but, keep coming back to this product. Product performance is great, I was looking for the best products for my new HE washer and dryer and after some research found the liquid detergent was the best.  Consumer Reports ranks this as the best High Efficiency (HE) product for Front loaders and #2 for Top Loaders ( was #1).My clothes come out super clean, fresh and smelling nice. Never any complaints about this one!',
#      'review_author': '/gp/profile/amzn1.account.AEFB56P7SH6PBJTGPDL53EHIDXLA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 7, 27, 0, 0),
#      'review_body': 'Pas mal. Mais sans plus. Je note ce produit après avoir découvert d\'autres produits de Tide, et celui-ci ne fait pas le poids à côté des deux autres que j\'ai pu acheter, notamment, le "Tide Plus Downy April Fresh Scent HE Turbo Clean Liquid Laundry Detergent" et le "Tide Plus Bleach Alternative HE Turbo Clean Liquid Laundry Detergent".',
#      'review_author': '/gp/profile/amzn1.account.AHWRZRWXFIMAEFEF6ZTHCMZT5CNA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 11, 11, 0, 0),
#      'review_body': 'I thought I was getting a larger container at a really good price - but this container isn’t the standard size you see at the grocery stores, instead it’s like a mini version that you see at convenience stores, dorm rooms or when you go camping. However, the Tide detergent in the bottle works great as usual. Just make sure you read the actual container size and detergent amounts before buying.',
#      'review_author': '/gp/profile/amzn1.account.AHYUSLQER5NXOGEEMBJK4LSH6O2A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 2, 6, 0, 0),
#      'review_body': 'Ehh',
#      'review_author': '/gp/profile/amzn1.account.AHOBTACH73AVOS2Z3FJY554PMPYA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 3, 3, 0, 0),
#      'review_body': 'I love the scent of Tide and find it not only gets my clothes clean but also gets them fresh.  I have piles of laundry.  In fact, some weeks I have a mountain of laundry.  For years, I have been able to trust Tide to do just what it advertises, clean my close.I got this on sale and find Amazon is the best place to pick it up.  I highly recommend this product.Feel free to ask questions. [...]',
#      'review_author': '/gp/profile/amzn1.account.AGZITZCHLTLG3VJIQQWUBJBWVDRA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 4, 13, 0, 0),
#      'review_body': 'I love the scent of Tide and find it not only gets my clothes clean but also gets them fresh.  I have piles of laundry.  In fact, some weeks I have a mountain of laundry.  For years, I have been able to trust Tide to do just what it advertises, clean my close.I got this on sale and find Amazon is the best place to pick it up.  I highly recommend this product.Feel free to ask questions. If this review was helpful in any way please click the "helpful" button below.',
#      'review_author': '/gp/profile/amzn1.account.AGZITZCHLTLG3VJIQQWUBJBWVDRA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 4, 7, 0, 0),
#      'review_body': 'We have been using this same liquid detergent for almost 9 years now and is our favourite product. We have tried many other products in between, but, keep coming back to this product. Product performance is great, I was looking for the best products for my new HE washer and dryer and after some research found the liquid detergent was the best.  Consumer Reports ranks this as the best High Efficiency (HE) product for Front loaders and #2 for Top Loaders ( was #1).My clothes come out super clean, fresh and smelling nice. Never any complaints about this one!',
#      'review_author': '/gp/profile/amzn1.account.AEFB56P7SH6PBJTGPDL53EHIDXLA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 7, 23, 0, 0),
#      'review_body': 'I absolutely love tide. Glad to get household supplies right to my home!',
#      'review_author': '/gp/profile/amzn1.account.AGAVMQWNG3QQLSQDXBNBGIGAITUA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 2, 9, 0, 0),
#      'review_body': 'I have been using this product for many years, and am very satisfied with it, especially the family size.',
#      'review_author': '/gp/profile/amzn1.account.AE42DLWI3I527GDKV2FHXALAMQIA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 5, 18, 0, 0),
#      'review_body': 'I always love tide. Been using this for long.',
#      'review_author': '/gp/profile/amzn1.account.AGS3O5UDGZPFFXRM65SYBOVP3OQQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 9, 20, 0, 0),
#      'review_body': "It's Tide, if you've never heard of it, welcome to the 21st century.",
#      'review_author': '/gp/profile/amzn1.account.AEPB37A6JVFTTCU2EIGRS2IO5O3A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 11, 3, 0, 0),
#      'review_body': "Works well, but the price is a bit higher than I've found locally.",
#      'review_author': '/gp/profile/amzn1.account.AFZANVBVGTEVXSDCSN3RD27HZFGQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2018, 7, 3, 0, 0),
#      'review_body': 'Good if you get it on sale.',
#      'review_author': '/gp/profile/amzn1.account.AFBYWWE5HWRFDCBL23T7WZMDINYA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 10, 18, 0, 0),
#      'review_body': 'Cheap detergent in a small, easy to tote container.',
#      'review_author': '/gp/profile/amzn1.account.AEQZBR6BE3HK66GZIGVRG5PGAURA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 9, 3, 0, 0),
#      'review_body': 'Nothing cleans better than Tide. Great detergent',
#      'review_author': '/gp/profile/amzn1.account.AFODRIBERAXHJJQW6OFF7A6UVP7Q/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 8, 17, 0, 0),
#      'review_body': 'No complaints. Clothes come out smelling fresh and clean.',
#      'review_author': '/gp/profile/amzn1.account.AEPCJBKQBYHUQU43PUHKMSN37ZFQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 10, 26, 0, 0),
#      'review_body': 'Great product and service',
#      'review_author': '/gp/profile/amzn1.account.AHCNGITDW64WS4Y65HDZWQF6P6LA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 1, 25, 0, 0),
#      'review_body': 'smells great and the price is great as well',
#      'review_author': '/gp/profile/amzn1.account.AEZX4CJYK64ZCBUI7YFGGA5DXZHA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 6, 27, 0, 0),
#      'review_body': 'good product as expected',
#      'review_author': '/gp/profile/amzn1.account.AEZJH3VCPZ57NIGDHEDSYARKPJJQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 10, 17, 0, 0),
#      'review_body': 'As expected',
#      'review_author': '/gp/profile/amzn1.account.AEK4ZIJA2HOLKRVH6SBQ3O5XHB7A/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 11, 30, 0, 0),
#      'review_body': 'Excellent product',
#      'review_author': '/gp/profile/amzn1.account.AHDHJCG42CCIOKTMS67NK5TWVYSA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 12, 22, 0, 0),
#      'review_body': 'Just as good as Costco but less hassle !',
#      'review_author': '/gp/profile/amzn1.account.AGVQQ34IXCPJC5AHJXC75ZYYDUXQ/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2017, 9, 30, 0, 0),
#      'review_body': 'The same as what is sold at store,recommend.',
#      'review_author': '/gp/profile/amzn1.account.AH53RKJ5G5Q3ZRCALJ27M5KQYPAA/ref=cm_cr_arp_d_pdp?ie=UTF8'},
#     {'review_date': datetime.datetime(2016, 11, 21, 0, 0),
#      'review_body': 'awesome price',
#      'review_author': '/gp/profile/amzn1.account.AGYZ5CWVZAIYALH4AJJ3KF26ZQMA/ref=cm_cr_arp_d_pdp?ie=UTF8'}]},
#   'details': {'price': '17.88',
#    'name': 'Tide High Efficiency Turbo Clean Liquid Laundry Detergent, Original Scent, 4.43 L (96 Loads)'}}}
